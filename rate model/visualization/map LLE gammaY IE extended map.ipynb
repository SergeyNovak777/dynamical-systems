# %%
if Sys.iswindows()
    username = "Alex"
    pathtorepo = "C:\\Users\\" *username *  "\\Desktop\\"
    using Pkg
    Pkg.activate(pathtorepo * "dynamical-systems\\env\\integrate\\")
else
    username = "sergey"
    pathtorepo = "/home/" *username *"/work/repo/dynamical-systems"
    using Pkg
    Pkg.activate(pathtorepo * "/env/integrate/")
end
# Out:
#   Activating project at `~/work/repo/dynamical-systems/env/integrate`

# %%
using JLD2, CairoMakie

# %%
cd("/home/sergey/work/repo/dynamical-systems/rate model/Map LSE(LLE)/files_extended_map/")
namefile_LSE = "LSE_400x400_γY_IE.jld2"
namefile_u0s = "u0s_400x400_γY_IE.jld2"
len = 400
Λs = load(namefile_LSE)
Λs = Λs["λs"]
u0s = load(namefile_u0s)
init_points = u0s["init_points"]
last_points = u0s["last_points"]

γYrange = range( 0.0, 100.0, length = len );
IErange = range(0.0, 2.0, length = len);

# %%
index = 1
absmax = maximum(abs.(Λs[:, :, index]))

mn, mx =  -absmax, absmax

f = Figure()
ticksize = 35
tickpad = 10.0
textsize = 30
textsizecurve = 35
lw = 2.5
mksize = 12
colorhopf = :red
colorfold = :lime

ax = Axis(f[1, 1], xlabel = L"γY",ylabel = L"IE", xlabelsize = 50, ylabelsize = 50,
            xticklabelsize = ticksize, yticklabelsize = ticksize,
            xgridvisible  = false, ygridvisible = false,
            xticklabelpad = tickpad, yticklabelpad = tickpad)

hm = heatmap!(ax, γYrange, IErange, Λs[:, :, index], colormap = :seismic, colorrange = (mn, mx))
Colorbar(f[:, end+1], hm)
display(f)
# Out:
# CairoMakie.Screen{IMAGE}
