# %%
using Pkg
Pkg.activate("C:\\Users\\Alex\\Desktop\\repo\\2612\\0903\\dynamical-systems\\env\\integrate\\")

using CairoMakie, DelimitedFiles
# Out:
#   Activating project at `C:\Users\Alex\Desktop\repo\2612\0903\dynamical-systems\env\integrate`

# %%
spectrum = readdlm("Test_LS.txt"); println(size(spectrum)[1])
u0s = readdlm("Test_u0s.txt");
# Out:
# 93

# %%
Px_start = -0.5; Px_end = -2.0
Py_start = 0.22; Py_end = 0.55;

# %%
f = Figure()
ax = Axis(f[1, 1], xlabel = L"I0", ylabel = "U0", xlabelsize = 25, ylabelsize = 25,
            xticklabelsize = 18, yticklabelsize = 18)


h = scatter!(spectrum[:, 3], spectrum[:, 4], markersize = 20, color = spectrum[:, 5], colormap = :bwr)

#lims!(Px_end, Px_start)
#ylims!(Py_start, Py_end)
Colorbar(f[1, 2], h)
f
