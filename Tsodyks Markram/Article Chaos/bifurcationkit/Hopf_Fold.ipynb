# %%
user = "Alex"
pathtorepo = "C:\\Users\\" *user *  "\\Desktop\\"
using Pkg
Pkg.activate(pathtorepo * "dynamical-systems\\env\\bifurcation\\")
# Out:
#   Activating project at `C:\Users\Alex\Desktop\dynamical-systems\env\bifurcation`

# %%
using BifurcationKit, LinearAlgebra, Plots, Parameters, JLD2
const BK = BifurcationKit
# Out:
# WARNING: using Plots.wrap in module BifurcationKit conflicts with an existing identifier.
# BifurcationKit

# %%
τ_ = 0.013; τD_ = 0.07993;  τy_ = 3.3; J_ = 3.07; β_ = 0.300
xthr_ = 0.75; ythr_ = 0.4
α_ = 1.58; ΔU0_ = 0.305
I0_ = -1.7064; U0_ = 0.265; 

@inbounds function TM_bk!(du, u, p, t = 0)
    U_ = p[8] + p[9] / ( 1.0 + exp( -50.0 * (u[3] - p[7]) ) )
    σ = 1.0 / ( 1.0 + exp( -20.0 * (u[2]-p[6]) ) )
    g(E, x, y, p, U_) = log( 1.0 + exp( (p[5] * U_ * x * E + p[11]  ) / (p[1]) ) )
    
    du[1] = (-u[1] + p[1] * g(u[1], u[2], u[3], p, U_) ) / p[2]
    du[2] = (1.0 - u[2]) / p[3] - U_*u[2]*u[1]
    du[3] = (-u[3])/p[4] + p[10] * σ
    
    return du
end
# Out:
# TM_bk! (generic function with 2 methods)

# %%
TM_bk(u, p) = TM_bk!(similar(u), u, p, 0)

p_tm = (α = α_, τ = τ_, τD = τD_, τy = τy_, J = J_, xthr = xthr_, ythr = ythr_, U0 = U0_, ΔU0 = ΔU0_, β = β_, I0 = I0_)
fp0 = [ 8.34581,  0.738495,  0.438299];

prob =  BifurcationProblem(TM_bk, fp0, p_tm, (@lens _.I0))

opt_new = NewtonPar(maxIter = 3, tol = 1e-6)
pmax, pmin = 0.0, -1.74

opts_con = ContinuationPar(pMin = pmin, pMax = pmax,
                            ds = 0.001, dsmin = 1e-5, dsmax = 0.1,
                            nev = 3, detectBifurcation = 3, newtonOptions  = opt_new,
                            maxSteps  = 300, nInversion = 6)
# Out:
# ContinuationPar{Float64, DefaultLS, DefaultEig{typeof(real)}}
#   dsmin: Float64 1.0e-5
#   dsmax: Float64 0.1
#   ds: Float64 0.001
#   a: Float64 0.5
#   pMin: Float64 -1.74
#   pMax: Float64 0.0
#   maxSteps: Int64 300
#   newtonOptions: NewtonPar{Float64, DefaultLS, DefaultEig{typeof(real)}}
#   η: Float64 150.0
#   saveToFile: Bool false
#   saveSolEveryStep: Int64 1
#   nev: Int64 3
#   saveEigEveryStep: Int64 1
#   saveEigenvectors: Bool true
#   plotEveryStep: Int64 10
#   tolStability: Float64 1.0e-10
#   detectFold: Bool true
#   detectBifurcation: Int64 3
#   dsminBisection: Float64 1.0e-16
#   nInversion: Int64 6
#   maxBisectionSteps: Int64 15
#   tolBisectionEigenvalue: Float64 1.0e-16
#   detectEvent: Int64 0
#   tolParamBisectionEvent: Float64 1.0e-16
#   detectLoop: Bool false

# %%
br = continuation(prob, PALC(), opts_con)

plot(br)

# %%
hp_codim2_1 = continuation(br, 1, (@lens _.U0),
    ContinuationPar(opts_con, pMin = 0.0, pMax = 0.55,
        ds = 0.001, dsmax = 0.1, dsmin = 1e-5),
    # detection of codim 2 bifurcations with bisection
    detectCodim2Bifurcation = 2,
    # tell to start the Hopf problem using eigen elements: compute left eigenvector
    startWithEigen = true,
    # we update the Hopf problem at every continuation step
    updateMinAugEveryStep = 1,
    # compute both sides of the initial condition
    bothside = true,
    verbosity = 3
    )
plot(hp_codim2_1)
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ────────────────── PALC ──────────────────
# ━━━━━━━━━━━━━━━━━━  INITIAL GUESS   ━━━━━━━━━━━━━━━━━━
# ──▶ convergence of initial guess = OK
#
# ──▶ parameter = 0.265, initial step
# ━━━━━━━━━━━━━━━━━━ INITIAL TANGENT  ━━━━━━━━━━━━━━━━━━
# ──▶ convergence of the initial guess = OK
#
# ──▶ parameter = 0.26500666666666667, initial step (bis)
# Predictor:  Secant
# ───────────────────────────────────────────────────────
# Continuation Step 0
# Step size = 1.0000e-03
# Parameter U0
#  = 2.6500e-01 ⟶  2.6508e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6500e-01 ⟶  2.6508e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.201638308453745, -0.1554443903466805, 0)
#               ──> (16.204670354929423, -0.15536291725154225, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 1
# Step size = 1.2222e-03
# Parameter U0 = 2.6508e-01 ⟶  2.6517e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6508e-01 ⟶  2.6517e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.204670354929423, -0.15536291725154225, 0)
#               ──> (16.20837571399167, -0.1552634966422905, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 2
# Step size = 1.4938e-03
# Parameter U0 = 2.6517e-01 ⟶  2.6528e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6517e-01 ⟶  2.6528e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.20837571399167, -0.1552634966422905, 0)
#               ──> (16.212904334887664, -0.15514209987500982, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 3
# Step size = 1.8258e-03
# Parameter U0 = 2.6528e-01 ⟶  2.6542e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6528e-01 ⟶  2.6543e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.212904334887664, -0.15514209987500982, 0)
#               ──> (16.218439089473918, -0.1549939004079226, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 4
# Step size = 2.2315e-03
# Parameter U0 = 2.6543e-01 ⟶  2.6560e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6543e-01 ⟶  2.6560e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.218439089473918, -0.1549939004079226, 0)
#               ──> (16.225203449268793, -0.15481302660820218, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 5
# Step size = 2.7274e-03
# Parameter U0 = 2.6560e-01 ⟶  2.6581e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6560e-01 ⟶  2.6581e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.225203449268793, -0.15481302660820218, 0)
#               ──> (16.233470488343613, -0.15459234244316927, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 6
# Step size = 3.3335e-03
# Parameter U0 = 2.6581e-01 ⟶  2.6607e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6581e-01 ⟶  2.6607e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.233470488343613, -0.15459234244316927, 0)
#               ──> (16.243573876174757, -0.15432318532329242, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 7
# Step size = 4.0743e-03
# Parameter U0 = 2.6607e-01 ⟶  2.6639e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6607e-01 ⟶  2.6639e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.243573876174757, -0.15432318532329242, 0)
#               ──> (16.255921297318853, -0.15399505400263686, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 8
# Step size = 4.9797e-03
# Parameter U0 = 2.6639e-01 ⟶  2.6679e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6639e-01 ⟶  2.6679e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.255921297318853, -0.15399505400263686, 0)
#               ──> (16.27101082814067, -0.15359523867599267, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 9
# Step size = 6.0863e-03
# Parameter U0 = 2.6679e-01 ⟶  2.6728e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6679e-01 ⟶  2.6728e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.27101082814067, -0.15359523867599267, 0)
#               ──> (16.289450913047446, -0.1531083844702647, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 10
# Step size = 7.4388e-03
# Parameter U0 = 2.6728e-01 ⟶  2.6789e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6728e-01 ⟶  2.6789e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.289450913047446, -0.1531083844702647, 0)
#               ──> (16.31198471593426, -0.15251597799842095, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 11
# Step size = 9.0918e-03
# Parameter U0 = 2.6789e-01 ⟶  2.6864e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6789e-01 ⟶  2.6866e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.31198471593426, -0.15251597799842095, 0)
#               ──> (16.339519778185426, -0.15179574340985252, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 12
# Step size = 1.1112e-02
# Parameter U0 = 2.6866e-01 ⟶  2.6959e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 2.6866e-01 ⟶  2.6961e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.339519778185426, -0.15179574340985252, 0)
#               ──> (16.373164091031377, -0.15092092660431294, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 13
# Step size = 1.3582e-02
# Parameter U0 = 2.6961e-01 ⟶  2.7078e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.6961e-01 ⟶  2.7081e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.373164091031377, -0.15092092660431294, 0)
#               ──> (16.414269888418637, -0.1498594228720328, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 14
# Step size = 1.4336e-02
# Parameter U0 = 2.7081e-01 ⟶  2.7208e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.7081e-01 ⟶  2.7213e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.414269888418637, -0.1498594228720328, 0)
#               ──> (16.45764041891007, -0.14874749622622707, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 15
# Step size = 1.5133e-02
# Parameter U0 = 2.7213e-01 ⟶  2.7351e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.7213e-01 ⟶  2.7357e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.45764041891007, -0.14874749622622707, 0)
#               ──> (16.503397988991882, -0.14758243192354384, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 16
# Step size = 1.5973e-02
# Parameter U0 = 2.7357e-01 ⟶  2.7509e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.7357e-01 ⟶  2.7515e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.503397988991882, -0.14758243192354384, 0)
#               ──> (16.551670832978427, -0.146361112934238, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 17
# Step size = 1.6861e-02
# Parameter U0 = 2.7515e-01 ⟶  2.7682e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.7515e-01 ⟶  2.7690e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.551670832978427, -0.146361112934238, 0)
#               ──> (16.602593124241896, -0.1450798681251697, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 18
# Step size = 1.7797e-02
# Parameter U0 = 2.7690e-01 ⟶  2.7875e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.7690e-01 ⟶  2.7884e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.602593124241896, -0.1450798681251697, 0)
#               ──> (16.65630484652338, -0.14373425023033737, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 19
# Step size = 1.8786e-02
# Parameter U0 = 2.7884e-01 ⟶  2.8089e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.7884e-01 ⟶  2.8101e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.65630484652338, -0.14373425023033737, 0)
#               ──> (16.712951411864417, -0.14231869995337892, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 20
# Step size = 1.9830e-02
# Parameter U0 = 2.8101e-01 ⟶  2.8330e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.8101e-01 ⟶  2.8344e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.712951411864417, -0.14231869995337892, 0)
#               ──> (16.77268283429139, -0.14082602193677074, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 21
# Step size = 2.0932e-02
# Parameter U0 = 2.8344e-01 ⟶  2.8601e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.8344e-01 ⟶  2.8620e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.77268283429139, -0.14082602193677074, 0)
#               ──> (16.83565209119447, -0.139246534744283, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 22
# Step size = 2.2094e-02
# Parameter U0 = 2.8620e-01 ⟶  2.8911e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.8620e-01 ⟶  2.8935e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.83565209119447, -0.139246534744283, 0)
#               ──> (16.902011911827046, -0.13756662145623955, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 23
# Step size = 2.3322e-02
# Parameter U0 = 2.8935e-01 ⟶  2.9268e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.8935e-01 ⟶  2.9301e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.902011911827046, -0.13756662145623955, 0)
#               ──> (16.971908277972627, -0.13576609154400754, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 24
# Step size = 2.4618e-02
# Parameter U0 = 2.9301e-01 ⟶  2.9688e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.9301e-01 ⟶  2.9734e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.971908277972627, -0.13576609154400754, 0)
#               ──> (17.04546630499851, -0.13381293798490596, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 25
# Step size = 2.5985e-02
# Parameter U0 = 2.9734e-01 ⟶  3.0191e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 2.9734e-01 ⟶  3.0260e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.04546630499851, -0.13381293798490596, 0)
#               ──> (17.122755730036584, -0.13165154118362307, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 26
# Step size = 2.7429e-02
# Parameter U0 = 3.0260e-01 ⟶  3.0816e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.0260e-01 ⟶  3.0931e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.122755730036584, -0.13165154118362307, 0)
#               ──> (17.203688717686955, -0.12917058571797543, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 27
# Step size = 2.8953e-02
# Parameter U0 = 3.0931e-01 ⟶  3.1639e-01 [guess]
# ──> Step Converged in 3 Nonlinear Iteration(s)
# Parameter U0 = 3.0931e-01 ⟶  3.1872e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.203688717686955, -0.12917058571797543, 0)
#               ──> (17.28759204932974, -0.12608057451700472, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 28
# Step size = 2.8953e-02
# Parameter U0 = 3.1872e-01 ⟶  3.2810e-01 [guess]
# Newton correction failed
# Halve ds = 0.014476301864377178
# Predictor:  Secant
# ───────────────────────────────────────────────────────
# Continuation Step 28
# Step size = 1.4476e-02
# Parameter U0 = 3.1872e-01 ⟶  3.2341e-01 [guess]
# ──> Step Converged in 3 Nonlinear Iteration(s)
# Parameter U0 = 3.1872e-01 ⟶  3.2531e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.28759204932974, -0.12608057451700472, 0)
#               ──> (17.327903430448444, -0.12411357189103263, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 29
# Step size = 1.4476e-02
# Parameter U0 = 3.2531e-01 ⟶  3.3186e-01 [guess]
# ──> Step Converged in 3 Nonlinear Iteration(s)
# Parameter U0 = 3.2531e-01 ⟶  3.3567e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.327903430448444, -0.12411357189103263, 0)
#               ──> (17.363642476708723, -0.12124803689191048, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 30
# Step size = 1.4476e-02
# Parameter U0 = 3.3567e-01 ⟶  3.4574e-01 [guess]
# Newton correction failed
# Halve ds = 0.007238150932188589
# Predictor:  Secant
# ───────────────────────────────────────────────────────
# Continuation Step 30
# Step size = 7.2382e-03
# Parameter U0 = 3.3567e-01 ⟶  3.4070e-01 [guess]
# Newton correction failed
# Halve ds = 0.0036190754660942945
# Predictor:  Secant
# ───────────────────────────────────────────────────────
# Continuation Step 30
# Step size = 3.6191e-03
# Parameter U0 = 3.3567e-01 ⟶  3.3818e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.3567e-01 ⟶  3.3981e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.363642476708723, -0.12124803689191048, 0)
#               ──> (17.369215362995366, -0.12015458287163637, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 31
# Step size = 3.8201e-03
# Parameter U0 = 3.3981e-01 ⟶  3.4377e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.3981e-01 ⟶  3.4482e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.369215362995366, -0.12015458287163637, 0)
#               ──> (17.369711097644974, -0.11885772834993442, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 32
# Step size = 4.0324e-03
# Parameter U0 = 3.4482e-01 ⟶  3.4961e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.4482e-01 ⟶  3.4979e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.369711097644974, -0.11885772834993442, 0)
#               ──> (17.363743511505614, -0.11759085679477477, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 33
# Step size = 4.2564e-03
# Parameter U0 = 3.4979e-01 ⟶  3.5442e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.4979e-01 ⟶  3.5378e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.363743511505614, -0.11759085679477477, 0)
#               ──> (17.35447270811856, -0.11657954832219306, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 34
# Step size = 4.4929e-03
# Parameter U0 = 3.5378e-01 ⟶  3.5779e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.5378e-01 ⟶  3.5719e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.35447270811856, -0.11657954832219306, 0)
#               ──> (17.343466785225264, -0.11571418762805533, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 35
# Step size = 4.7425e-03
# Parameter U0 = 3.5719e-01 ⟶  3.6075e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.5719e-01 ⟶  3.6029e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.343466785225264, -0.11571418762805533, 0)
#               ──> (17.33110387807536, -0.11492741102029166, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 36
# Step size = 5.0059e-03
# Parameter U0 = 3.6029e-01 ⟶  3.6355e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.6029e-01 ⟶  3.6319e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.33110387807536, -0.11492741102029166, 0)
#               ──> (17.317557848716813, -0.11418897016772706, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 37
# Step size = 5.2840e-03
# Parameter U0 = 3.6319e-01 ⟶  3.6623e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.6319e-01 ⟶  3.6594e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.317557848716813, -0.11418897016772706, 0)
#               ──> (17.30290736275323, -0.1134813114536729, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 38
# Step size = 5.5776e-03
# Parameter U0 = 3.6594e-01 ⟶  3.6884e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.6594e-01 ⟶  3.6860e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.30290736275323, -0.1134813114536729, 0)
#               ──> (17.287179667216545, -0.11279281547846233, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 39
# Step size = 5.8875e-03
# Parameter U0 = 3.6860e-01 ⟶  3.7140e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.6860e-01 ⟶  3.7119e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.287179667216545, -0.11279281547846233, 0)
#               ──> (17.27037257338063, -0.11211514706040873, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 40
# Step size = 6.2145e-03
# Parameter U0 = 3.7119e-01 ⟶  3.7392e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.7119e-01 ⟶  3.7373e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.27037257338063, -0.11211514706040873, 0)
#               ──> (17.252465543579135, -0.11144194173687219, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 41
# Step size = 6.5598e-03
# Parameter U0 = 3.7373e-01 ⟶  3.7641e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.7373e-01 ⟶  3.7624e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.252465543579135, -0.11144194173687219, 0)
#               ──> (17.23342555998441, -0.11076807386167362, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 42
# Step size = 6.9242e-03
# Parameter U0 = 3.7624e-01 ⟶  3.7890e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.7624e-01 ⟶  3.7874e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.23342555998441, -0.11076807386167362, 0)
#               ──> (17.213210376360244, -0.11008921592969548, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 43
# Step size = 7.3089e-03
# Parameter U0 = 3.7874e-01 ⟶  3.8137e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.7874e-01 ⟶  3.8123e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.213210376360244, -0.11008921592969548, 0)
#               ──> (17.19177038070574, -0.10940155656267958, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 44
# Step size = 7.7149e-03
# Parameter U0 = 3.8123e-01 ⟶  3.8386e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.8123e-01 ⟶  3.8372e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.19177038070574, -0.10940155656267958, 0)
#               ──> (17.169049679504848, -0.10870161009646974, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 45
# Step size = 8.1436e-03
# Parameter U0 = 3.8372e-01 ⟶  3.8635e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.8372e-01 ⟶  3.8622e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.169049679504848, -0.10870161009646974, 0)
#               ──> (17.144986723397395, -0.10798608129547768, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 46
# Step size = 8.5960e-03
# Parameter U0 = 3.8622e-01 ⟶  3.8887e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.8622e-01 ⟶  3.8874e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.144986723397395, -0.10798608129547768, 0)
#               ──> (17.119514649773038, -0.10725176418847004, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 47
# Step size = 9.0735e-03
# Parameter U0 = 3.8874e-01 ⟶  3.9140e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.8874e-01 ⟶  3.9128e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.119514649773038, -0.10725176418847004, 0)
#               ──> (17.092561442639308, -0.10649546231789889, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 48
# Step size = 9.5776e-03
# Parameter U0 = 3.9128e-01 ⟶  3.9397e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.9128e-01 ⟶  3.9385e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.092561442639308, -0.10649546231789889, 0)
#               ──> (17.064049969225, -0.10571392235391769, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 49
# Step size = 1.0110e-02
# Parameter U0 = 3.9385e-01 ⟶  3.9656e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.9385e-01 ⟶  3.9645e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.064049969225, -0.10571392235391769, 0)
#               ──> (17.033897929628708, -0.10490377573351096, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 50
# Step size = 1.0671e-02
# Parameter U0 = 3.9645e-01 ⟶  3.9920e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.9645e-01 ⟶  3.9909e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.033897929628708, -0.10490377573351096, 0)
#               ──> (17.00201774223903, -0.10406148459869521, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 51
# Step size = 1.1264e-02
# Parameter U0 = 3.9909e-01 ⟶  4.0188e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 3.9909e-01 ⟶  4.0177e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (17.00201774223903, -0.10406148459869521, 0)
#               ──> (16.968316379424422, -0.10318328927907802, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 52
# Step size = 1.1890e-02
# Parameter U0 = 4.0177e-01 ⟶  4.0460e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.0177e-01 ⟶  4.0449e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.968316379424422, -0.10318328927907802, 0)
#               ──> (16.93269516285475, -0.10226515514146359, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 53
# Step size = 1.2551e-02
# Parameter U0 = 4.0449e-01 ⟶  4.0737e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.0449e-01 ⟶  4.0726e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.93269516285475, -0.10226515514146359, 0)
#               ──> (16.895049524523564, -0.10130271695356972, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 54
# Step size = 1.3248e-02
# Parameter U0 = 4.0726e-01 ⟶  4.1019e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.0726e-01 ⟶  4.1009e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.895049524523564, -0.10130271695356972, 0)
#               ──> (16.855268737376385, -0.10029121906024943, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 55
# Step size = 1.3984e-02
# Parameter U0 = 4.1009e-01 ⟶  4.1307e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.1009e-01 ⟶  4.1297e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.855268737376385, -0.10029121906024943, 0)
#               ──> (16.81323561798999, -0.09922544969428815, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 56
# Step size = 1.4761e-02
# Parameter U0 = 4.1297e-01 ⟶  4.1600e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.1297e-01 ⟶  4.1590e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.81323561798999, -0.09922544969428815, 0)
#               ──> (16.768826202744933, -0.09809966766383374, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 57
# Step size = 1.5581e-02
# Parameter U0 = 4.1590e-01 ⟶  4.1900e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.1590e-01 ⟶  4.1890e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.768826202744933, -0.09809966766383374, 0)
#               ──> (16.72190939822521, -0.09690751948497178, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 58
# Step size = 1.6446e-02
# Parameter U0 = 4.1890e-01 ⟶  4.2207e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.1890e-01 ⟶  4.2197e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.72190939822521, -0.09690751948497178, 0)
#               ──> (16.672346606073095, -0.09564194476011038, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 59
# Step size = 1.7360e-02
# Parameter U0 = 4.2197e-01 ⟶  4.2520e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.2197e-01 ⟶  4.2510e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.672346606073095, -0.09564194476011038, 0)
#               ──> (16.61999132216016, -0.09429506723217279, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 60
# Step size = 1.8324e-02
# Parameter U0 = 4.2510e-01 ⟶  4.2841e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.2510e-01 ⟶  4.2831e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.61999132216016, -0.09429506723217279, 0)
#               ──> (16.5646887096682, -0.0928580684533955, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 61
# Step size = 1.9342e-02
# Parameter U0 = 4.2831e-01 ⟶  4.3169e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.2831e-01 ⟶  4.3159e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.5646887096682, -0.0928580684533955, 0)
#               ──> (16.50627514548514, -0.09132104036874863, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 62
# Step size = 2.0417e-02
# Parameter U0 = 4.3159e-01 ⟶  4.3506e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.3159e-01 ⟶  4.3495e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.50627514548514, -0.09132104036874863, 0)
#               ──> (16.444577739197978, -0.08967281228917584, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 63
# Step size = 2.1551e-02
# Parameter U0 = 4.3495e-01 ⟶  4.3850e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.3495e-01 ⟶  4.3840e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.444577739197978, -0.08967281228917584, 0)
#               ──> (16.37941382390476, -0.08790074666485986, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 64
# Step size = 2.2749e-02
# Parameter U0 = 4.3840e-01 ⟶  4.4203e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.3840e-01 ⟶  4.4193e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.37941382390476, -0.08790074666485986, 0)
#               ──> (16.310590418078046, -0.08599049668781153, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 65
# Step size = 2.4012e-02
# Parameter U0 = 4.4193e-01 ⟶  4.4565e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.4193e-01 ⟶  4.4555e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.310590418078046, -0.08599049668781153, 0)
#               ──> (16.23790365780861, -0.08392571695116889, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 66
# Step size = 2.5346e-02
# Parameter U0 = 4.4555e-01 ⟶  4.4937e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.4555e-01 ⟶  4.4926e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.23790365780861, -0.08392571695116889, 0)
#               ──> (16.161138198972303, -0.08168771602025462, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 67
# Step size = 2.6755e-02
# Parameter U0 = 4.4926e-01 ⟶  4.5318e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.4926e-01 ⟶  4.5307e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.161138198972303, -0.08168771602025462, 0)
#               ──> (16.08006658924596, -0.07925503661417505, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 68
# Step size = 2.8241e-02
# Parameter U0 = 4.5307e-01 ⟶  4.5710e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.5307e-01 ⟶  4.5699e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (16.08006658924596, -0.07925503661417505, 0)
#               ──> (15.994448610533746, -0.0766029448448755, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 69
# Step size = 2.9810e-02
# Parameter U0 = 4.5699e-01 ⟶  4.6111e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.5699e-01 ⟶  4.6100e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (15.994448610533746, -0.0766029448448755, 0)
#               ──> (15.90403059339137, -0.07370280415014566, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 70
# Step size = 3.1466e-02
# Parameter U0 = 4.6100e-01 ⟶  4.6524e-01 [guess]
# ──> Step Converged in 1 Nonlinear Iteration(s)
# Parameter U0 = 4.6100e-01 ⟶  4.6513e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (15.90403059339137, -0.07370280415014566, 0)
#               ──> (15.808544743680175, -0.07052131722098129, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 71
# Step size = 3.8458e-02
# Parameter U0 = 4.6513e-01 ⟶  4.7018e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.6513e-01 ⟶  4.7003e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (15.808544743680175, -0.07052131722098129, 0)
#               ──> (15.691782551048611, -0.06645240105999245, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 72
# Step size = 4.0595e-02
# Parameter U0 = 4.7003e-01 ⟶  4.7521e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.7003e-01 ⟶  4.7505e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (15.691782551048611, -0.06645240105999245, 0)
#               ──> (15.568471481159836, -0.06192481687744331, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 73
# Step size = 4.2850e-02
# Parameter U0 = 4.7505e-01 ⟶  4.8035e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.7505e-01 ⟶  4.8020e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (15.568471481159836, -0.06192481687744331, 0)
#               ──> (15.438247512724528, -0.05686402459804454, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 74
# Step size = 4.5231e-02
# Parameter U0 = 4.8020e-01 ⟶  4.8564e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.8020e-01 ⟶  4.8549e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (15.438247512724528, -0.05686402459804454, 0)
#               ──> (15.300727204673505, -0.05117979551033229, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 75
# Step size = 4.7744e-02
# Parameter U0 = 4.8549e-01 ⟶  4.9107e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.8549e-01 ⟶  4.9092e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (15.300727204673505, -0.05117979551033229, 0)
#               ──> (15.155507358693205, -0.04476169090034263, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 76
# Step size = 5.0396e-02
# Parameter U0 = 4.9092e-01 ⟶  4.9665e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.9092e-01 ⟶  4.9651e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (15.155507358693205, -0.04476169090034263, 0)
#               ──> (15.002165112335351, -0.037472724407299846, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 77
# Step size = 5.3196e-02
# Parameter U0 = 4.9651e-01 ⟶  5.0242e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 4.9651e-01 ⟶  5.0228e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (15.002165112335351, -0.037472724407299846, 0)
#               ──> (14.840258946670126, -0.02914009506393881, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 78
# Step size = 5.6151e-02
# Parameter U0 = 5.0228e-01 ⟶  5.0837e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 5.0228e-01 ⟶  5.0825e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (14.840258946670126, -0.02914009506393881, 0)
#               ──> (14.669331564273143, -0.01954090805158298, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 79
# Step size = 5.9271e-02
# Parameter U0 = 5.0825e-01 ⟶  5.1456e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 5.0825e-01 ⟶  5.1446e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (14.669331564273143, -0.01954090805158298, 0)
#               ──> (14.488916853330979, -0.00837854325216152, 0)
# ───────────────────────────────────────────────────────
# Continuation Step 80
# Step size = 6.2564e-02
# Parameter U0 = 5.1446e-01 ⟶  5.2101e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 5.1446e-01 ⟶  5.2096e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (14.488916853330979, -0.00837854325216152, 0)
#               ──> (14.298556697772813, 0.004760540151225588, 0)
# ──> Event detected before p = 0.5209558690223135
# ────> Entering [Event], indicator of 2 last events =
# ((2, 0), (1, 0))
# ────> [Bisection] initial ds = 0.06603932223733572
# ────> [Bisection] state.ds = -0.06603932223733572
# ──> eve (initial) (14.488916853330979, -0.00837854325216152, 0) ──> (14.298556697772813, 0.004760540151225588, 0)
#
# ──> eigvals =
# -3.0310176590830906e-9 - 14.298556703235175im
# -3.0310176590830906e-9 + 14.298556703235175im
# -3.2635568749029717 + 0.0im
#
# ────> eve (current) (14.298556697772813, 0.004760540151225588, 0) ──> (14.298556697772813, 0.004760540151225588, 0)
# ────> eigvals =
# -3.0310176590830906e-9 - 14.298556703235175im
# -3.0310176590830906e-9 + 14.298556703235175im
# -3.2635568749029717 + 0.0im
# ────> 0 - [Bisection] (n1, n_current, n2) = ((1, 0), (2, 0), (2, 0))
# 			ds = -0.03301966111866786, p = 0.5209558690223135, #reverse = 0
# ────> event ∈ (0.5144599311992005, 0.5209558690223135), precision = 6.496E-03
# Predictor:  Secant
#
# ────> eve (current) (14.298556697772813, 0.004760540151225588, 0) ──> (14.399002899784376, -0.002363368021448844, 0)
# ────> eigvals =
# -8.955058916626513e-13 - 14.399002899786487im
# -8.955058916626513e-13 + 14.399002899786487im
# -3.4839342978064316 + 0.0im
# ────> 1 - [Bisection] (n1, n_current, n2) = ((1, 0), (1, 0), (2, 0))
# 			ds = 0.01650983055933393, p = 0.5175308766262517, #reverse = 1
# ────> event ∈ (0.5175308766262517, 0.5209558690223135), precision = 3.425E-03
# Predictor:  Secant
# ────> eve (current) (14.399002899784376, -0.002363368021448844, 0) ──> (14.348774255826777, 0.0011428230059462169, 0)
# ────> eigvals =
# -1.9984014443252818e-15 - 14.348774255826774im
# -1.9984014443252818e-15 + 14.348774255826774im
# -3.374039036648799 + 0.0im
# ────> 2 - [Bisection] (n1, n_current, n2) = ((1, 0), (2, 0), (2, 0))
# 			ds = -0.008254915279666965, p = 0.5192436327645904, #reverse = 2
# ────> event ∈ (0.5175308766262517, 0.5192436327645904), precision = 1.713E-03
# Predictor:  Secant
#
# ────> eve (current) (14.348774255826777, 0.0011428230059462169, 0) ──> (14.373887265187097, -0.0006238126821803275, 0)
# ────> eigvals =
# -2.5920193547079862e-8 - 14.373887272635423im
# -2.5920193547079862e-8 + 14.373887272635423im
# -3.4290561733463383 + 0.0im
# ────> 3 - [Bisection] (n1, n_current, n2) = ((1, 0), (1, 0), (2, 0))
# 			ds = 0.004127457639833482, p = 0.5183874138615684, #reverse = 3
# ────> event ∈ (0.5183874138615684, 0.5192436327645904), precision = 8.562E-04
# Predictor:  Secant
#
# ────> eve (current) (14.373887265187097, -0.0006238126821803275, 0) ──> (14.361330427766115, 0.00025606995867619164, 0)
# ────> eigvals =
# -1.6698542548709838e-9 - 14.361330428249612im
# -1.6698542548709838e-9 + 14.361330428249612im
# -3.4015654691320223 + 0.0im
# ────> 4 - [Bisection] (n1, n_current, n2) = ((1, 0), (2, 0), (2, 0))
# 			ds = -0.002063728819916741, p = 0.5188155515173054, #reverse = 4
# ────> event ∈ (0.5183874138615684, 0.5188155515173054), precision = 4.281E-04
# Predictor:  Secant
#
# ────> eve (current) (14.361330427766115, 0.00025606995867619164, 0) ──> (14.36760876495201, -0.00018472530491708133, 0)
# ────> eigvals =
# -1.0282041884579485e-10 - 14.367608764981675im
# -1.0282041884579485e-10 + 14.367608764981675im
# -3.415315242988119 + 0.0im
# ────> 5 - [Bisection] (n1, n_current, n2) = ((1, 0), (1, 0), (2, 0))
# 			ds = 0.0010318644099583706, p = 0.5186014911152221, #reverse = 5
# ────> event ∈ (0.5186014911152221, 0.5188155515173054), precision = 2.141E-04
# Predictor:  Secant
#
# ────> eve (current) (14.36760876495201, -0.00018472530491708133, 0) ──> (14.364469575692926, 3.545837564979115e-5, 0)
# ────> eigvals =
# -6.489919712748815e-12 - 14.364469575694807im
# -6.489919712748815e-12 + 14.364469575694807im
# -3.408441465376213 + 0.0im
# ────> 6 - [Bisection] (n1, n_current, n2) = ((1, 0), (2, 0), (2, 0))
# 			ds = -0.0005159322049791853, p = 0.5187085232605007, #reverse = 6
# ────> event ∈ (0.5186014911152221, 0.5187085232605007), precision = 1.070E-04
# ────> Found at p = 0.5187085232605007 ∈ (0.5186014911152221, 0.5187085232605007),
# 			  δn = (1, 0), from p = 0.5209558690223135
# ────────────────────────────────────────
# ────> Stopping reason:
# ──────> isnothing(next)           = false
# ──────> |ds| < dsminBisection     = false
# ──────> step >= maxBisectionSteps = false
# ──────> n_inversion >= nInversion = true
# ──────> eventlocated              = false
# ────> Leaving [Loc-Bif]
# !! Continuous user point at p ≈ 0.5187085232605007
# ───────────────────────────────────────────────────────
# Continuation Step 81
# Step size = 6.6039e-02
# Parameter U0 = 5.1871e-01 ⟶  5.2556e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 5.1871e-01 ⟶  5.2557e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (14.364469575692926, 3.545837564979115e-5, 0)
#               ──> (14.163671947739713, 0.015091336382057015, 0)
# ──> Event detected before p = 0.5255678309253766
# ────> Entering [Event], indicator of 2 last events = ((2, 0), (2, 0))
# ────> [Bisection] initial ds = 0.06970817347274326
# ────> [Bisection] state.ds = -0.06970817347274326
# ──> eve (initial) (14.364469575692926, 3.545837564979115e-5, 0) ──> (14.163671947739713, 0.015091336382057015, 0)
#
# ──> eigvals =
# -1.4191625652415496e-10 - 14.163671948994162im
# -1.4191625652415496e-10 + 14.163671948994162im
# -2.963193221435385 + 0.0im
#
# ────> eve (current) (14.163671947739713, 0.015091336382057015, 0) ──> (14.163671947739713, 0.015091336382057015, 0)
# ────> eigvals =
# -1.4191625652415496e-10 - 14.163671948994162im
# -1.4191625652415496e-10 + 14.163671948994162im
# -2.963193221435385 + 0.0im
# ────> 0 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.03485408673637163, p = 0.5255678309253766, #reverse = 0
# ────> event ∈ (0.5187085232605007, 0.5255678309253766), precision = 6.859E-03
# Predictor:  Secant
#
# ────> eve (current) (14.163671947739713, 0.015091336382057015, 0) ──> (14.269611996673579, 0.00689946424506635, 0)
# ────> eigvals =
# -1.887379141862766e-14 - 14.269611996679261im
# -1.887379141862766e-14 + 14.269611996679261im
# -3.1995718670796545 + 0.0im
# ────> 1 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.017427043368185815, p = 0.5219433536138808, #reverse = 0
# ────> event ∈ (0.5187085232605007, 0.5219433536138808), precision = 3.235E-03
# Predictor:  Secant
#
# ────> eve (current) (14.269611996673579, 0.00689946424506635, 0) ──> (14.322612138795655, 0.0030131285902058116, 0)
# ────> eigvals =
# 5.120348589571222e-13 - 14.32261213879847im
# 5.120348589571222e-13 + 14.32261213879847im
# -3.316560997741689 + 0.0im
# ────> 2 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.008713521684092907, p = 0.5201355830949415, #reverse = 0
# ────> event ∈ (0.5187085232605007, 0.5201355830949415), precision = 1.427E-03
# Predictor:  Secant
#
# ────> eve (current) (14.322612138795655, 0.0030131285902058116, 0) ──> (14.349117348697387, 0.001118500026157189, 0)
# ────> eigvals =
# -1.509903313490213e-14 - 14.349117348697408im
# -1.509903313490213e-14 + 14.349117348697408im
# -3.3747916890008653 + 0.0im
# ────> 3 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.004356760842046454, p = 0.5192319358389125, #reverse = 0
# ────> event ∈ (0.5187085232605007, 0.5192319358389125), precision = 5.234E-04
# Predictor:  Secant
#
# ────> eve (current) (14.349117348697387, 0.001118500026157189, 0) ──> (14.3623711270204, 0.00018288640151471747, 0)
# ────> eigvals =
# -1.9238966642021182e-8 - 14.362371132555833im
# -1.9238966642021182e-8 + 14.362371132555833im
# -3.403845253582632 + 0.0im
# ────> 4 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.002178380421023227, p = 0.5187800695478224, #reverse = 0
# ────> event ∈ (0.5187085232605007, 0.5187800695478224), precision = 7.155E-05
# Predictor:  Secant
#
# ────> eve (current) (14.3623711270204, 0.00018288640151471747, 0) ──> (14.368998297110162, -0.00028205030965515465, 0)
# ────> eigvals =
# -1.171173380498658e-9 - 14.36899829744542im
# -1.171173380498658e-9 + 14.36899829744542im
# -3.4183571211298616 + 0.0im
# ────> 5 - [Bisection] (n1, n_current, n2) = ((2, 0), (1, 0), (2, 0))
# 			ds = 0.0010891902105116134, p = 0.5185541134728352, #reverse = 1
# ────> event ∈ (0.5185541134728352, 0.5187800695478224), precision = 2.260E-04
# Predictor:  Secant
#
# ────> eve (current) (14.368998297110162, -0.00028205030965515465, 0) ──> (14.365684690500098, -4.982114307398866e-5, 0)
# ────> eigvals =
# -8.038902876705833e-12 - 14.36568469050243im
# -8.038902876705833e-12 + 14.36568469050243im
# -3.411102434467643 + 0.0im
# ────> 6 - [Bisection] (n1, n_current, n2) = ((2, 0), (1, 0), (2, 0))
# 			ds = 0.0005445951052558067, p = 0.5186670936605199, #reverse = 1
# ────> event ∈ (0.5186670936605199, 0.5187800695478224), precision = 1.130E-04
# Predictor:  Secant
#
# ────> eve (current) (14.365684690500098, -4.982114307398866e-5, 0) ──> (14.364027904378592, 6.647185511318016e-5, 0)
# ────> eigvals =
# -4.4717562985852055e-12 - 14.364027904379874im
# -4.4717562985852055e-12 + 14.364027904379874im
# -3.4074741676910065 + 0.0im
# ────> 7 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.00027229755262790336, p = 0.5187235820452013, #reverse = 2
# ────> event ∈ (0.5186670936605199, 0.5187235820452013), precision = 5.649E-05
# Predictor:  Secant
#
# ────> eve (current) (14.364027904378592, 6.647185511318016e-5, 0) ──> (14.36485629598313, 8.310470999625674e-6, 0)
# ────> eigvals =
# -1.9095836023552692e-14 - 14.364856295983133im
# -1.9095836023552692e-14 + 14.364856295983133im
# -3.409288378160693 + 0.0im
# ────> 8 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.00013614877631395168, p = 0.5186953379906825, #reverse = 2
# ────> event ∈ (0.5186670936605199, 0.5186953379906825), precision = 2.824E-05
# Predictor:  Secant
#
# ────> eve (current) (14.36485629598313, 8.310470999625674e-6, 0) ──> (14.365270492870295, -2.075905529183575e-5, 0)
# ────> eigvals =
# -4.218847493575595e-15 - 14.365270492870312im
# -4.218847493575595e-15 + 14.365270492870312im
# -3.410195425554169 + 0.0im
# ────> 9 - [Bisection] (n1, n_current, n2) = ((2, 0), (1, 0), (2, 0))
# 			ds = 6.807438815697584e-5, p = 0.5186812158607162, #reverse = 3
# ────> event ∈ (0.5186812158607162, 0.5186953379906825), precision = 1.412E-05
# Predictor:  Secant
#
# ────> eve (current) (14.365270492870295, -2.075905529183575e-5, 0) ──> (14.365063394426887, -6.22170375932235e-6, 0)
# ────> eigvals =
# -3.820640093188388e-8 - 14.365063398730726im
# -3.820640093188388e-8 + 14.365063398730726im
# -3.4097418738408702 + 0.0im
# ────> 10 - [Bisection] (n1, n_current, n2) = ((2, 0), (1, 0), (2, 0))
# 			ds = 3.403719407848792e-5, p = 0.5186882769256934, #reverse = 3
# ────> event ∈ (0.5186882769256934, 0.5186953379906825), precision = 7.061E-06
# Predictor:  Secant
#
# ────> eve (current) (14.365063394426887, -6.22170375932235e-6, 0) ──> (14.364959845205183, 1.0450308086384918e-6, 0)
# ────> eigvals =
# -2.8654356887258814e-8 - 14.364959848433411im
# -2.8654356887258814e-8 + 14.364959848433411im
# -3.4095151189969477 + 0.0im
# ────> 11 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -1.701859703924396e-5, p = 0.518691807458182, #reverse = 4
# ────> event ∈ (0.5186882769256934, 0.518691807458182), precision = 3.531E-06
# Predictor:  Secant
#
# ────> eve (current) (14.364959845205183, 1.0450308086384918e-6, 0) ──> (14.365011619816036, -2.5881747933720334e-6, 0)
# ────> eigvals =
# ...
# 			ds = -0.025, p = 0.523915929163825, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.523915929163825), precision = 5.190E-03
# Predictor:  Secant
#
# ────> eve (current) (14.211878124009436, 0.011290203907698373, 0) ──> (14.287889858354792, 0.005544099230525686, 0)
# ────> eigvals =
# 3.3695934931188276e-11 - 14.287889858424222im
# 3.3695934931188276e-11 + 14.287889858424222im
# -3.240003903887298 + 0.0im
# ────> 2 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.0125, p = 0.5213197053413474, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.5213197053413474), precision = 2.594E-03
# Predictor:  Secant
#
# ────> eve (current) (14.287889858354792, 0.005544099230525686, 0) ──> (14.325907496244815, 0.0027758370328857737, 0)
# ────> eigvals =
# -8.881784197001252e-16 - 14.32590749624499im
# -8.881784197001252e-16 + 14.32590749624499im
# -3.323810325427687 + 0.0im
# ────> 3 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.00625, p = 0.5200232283795346, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.5200232283795346), precision = 1.297E-03
# Predictor:  Secant
#
# ────> eve (current) (14.325907496244815, 0.0027758370328857737, 0) ──> (14.344918970958911, 0.001416497443178233, 0)
# ────> eigvals =
# -1.3322676295501878e-14 - 14.344918970958911im
# -1.3322676295501878e-14 + 14.344918970958911im
# -3.365579627709092 + 0.0im
# ────> 4 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.003125, p = 0.5193750690392865, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.5193750690392865), precision = 6.490E-04
# Predictor:  Secant
#
# ────> eve (current) (14.344918970958911, 0.001416497443178233, 0) ──> (14.354425327672889, 0.0007428664042390329, 0)
# ────> eigvals =
# -5.0788666605683375e-9 - 14.354425329152798im
# -5.0788666605683375e-9 + 14.354425329152798im
# -3.386432329261575 + 0.0im
# ────> 5 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.0015625, p = 0.5190509717978847, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.5190509717978847), precision = 3.249E-04
# Predictor:  Secant
#
# ────> eve (current) (14.354425327672889, 0.0007428664042390329, 0) ──> (14.359178655776223, 0.00040754046294955854, 0)
# ────> eigvals =
# -3.115547819732001e-10 - 14.359178655866655im
# -3.115547819732001e-10 + 14.359178655866655im
# -3.3968508856205815 + 0.0im
# ────> 6 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.00078125, p = 0.5188889142462731, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.5188889142462731), precision = 1.629E-04
# Predictor:  Secant
#
# ────> eve (current) (14.359178655776223, 0.00040754046294955854, 0) ──> (14.361555356251744, 0.0002402480127350476, 0)
# ────> eigvals =
# -1.929789661403447e-11 - 14.36155535625733im
# -1.929789661403447e-11 + 14.36155535625733im
# -3.402058231847435 + 0.0im
# ────> 7 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.000390625, p = 0.518807882719293, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.518807882719293), precision = 8.182E-05
# Predictor:  Secant
#
# ────> eve (current) (14.361555356251744, 0.0002402480127350476, 0) ──> (14.362743715534279, 0.00015669408198998314, 0)
# ────> eigvals =
# -1.2276846206304981e-12 - 14.362743715534664im
# -1.2276846206304981e-12 + 14.362743715534664im
# -3.404661425234693 + 0.0im
# ────> 8 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.0001953125, p = 0.5187673661972689, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.5187673661972689), precision = 4.130E-05
# Predictor:  Secant
#
# ────> eve (current) (14.362743715534279, 0.00015669408198998314, 0) ──> (14.363337897427195, 0.00011494015143563574, 0)
# ────> eigvals =
# -7.682743330406083e-14 - 14.363337897427238im
# -7.682743330406083e-14 + 14.363337897427238im
# -3.405962902367123 + 0.0im
# ────> 9 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -9.765625e-5, p = 0.5187471077380185, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.5187471077380185), precision = 2.105E-05
# Predictor:  Secant
#
# ────> eve (current) (14.363337897427195, 0.00011494015143563574, 0) ──> (14.363634988935258, 9.406894020638074e-5, 0)
# ────> eigvals =
# 1.5765166949677223e-14 - 14.363634988935257im
# 1.5765166949677223e-14 + 14.363634988935257im
# -3.4066136110871303 + 0.0im
# ────> 10 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -4.8828125e-5, p = 0.5187369784577716, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.5187369784577716), precision = 1.092E-05
# Predictor:  Secant
#
# ────> eve (current) (14.363634988935258, 9.406894020638074e-5, 0) ──> (14.363783534689224, 8.362932954431718e-5, 0)
# ────> eigvals =
# 5.9039483746303745e-8 - 14.36378352803874im
# 5.9039483746303745e-8 + 14.36378352803874im
# -3.4069390087697955 + 0.0im
# ────> 11 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -2.44140625e-5, p = 0.5187319138176503, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.5187319138176503), precision = 5.851E-06
# Predictor:  Secant
#
# ────> eve (current) (14.363783534689224, 8.362932954431718e-5, 0) ──> (14.363857807811705, 7.841804811509895e-5, 0)
# ────> eigvals =
# 1.7541523789077473e-14 - 14.36385780781169im
# 1.7541523789077473e-14 + 14.36385780781169im
# -3.407101629579468 + 0.0im
# ────> 12 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -1.220703125e-5, p = 0.5187293814751923, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.5187293814751923), precision = 3.319E-06
# Predictor:  Secant
#
# ────> eve (current) (14.363857807811705, 7.841804811509895e-5, 0) ──> (14.363894944372896, 7.581215720234291e-5, 0)
# ────> eigvals =
# -2.5832681105342203e-8 - 14.363894947282112im
# -2.5832681105342203e-8 + 14.363894947282112im
# -3.407182942689362 + 0.0im
# ────> 13 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -6.103515625e-6, p = 0.518728115303965, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.518728115303965), precision = 2.053E-06
# Predictor:  Secant
#
# ────> eve (current) (14.363894944372896, 7.581215720234291e-5, 0) ──> (14.363913512653491, 7.450914920381635e-5, 0)
# ────> eigvals =
# -3.782727020507082e-8 - 14.363913516913307im
# -3.782727020507082e-8 + 14.363913516913307im
# -3.4072235999206026 + 0.0im
# ────> 14 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -3.0517578125e-6, p = 0.5187274822183514, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.5187274822183514), precision = 1.420E-06
# Predictor:  Secant
#
# ────> eve (current) (14.363913512653491, 7.450914920381635e-5, 0) ──> (14.363922796793789, 7.385762956457764e-5, 0)
# ────> eigvals =
# -4.359412608678781e-8 - 14.36392280170291im
# -4.359412608678781e-8 + 14.36392280170291im
# -3.4072439287052916 + 0.0im
# ────> 15 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -1.52587890625e-6, p = 0.5187271656755446, #reverse = 0
# ────> event ∈ (0.5187260624588579, 0.5187271656755446), precision = 1.103E-06
# ────> Found at p = 0.5187271656755446 ∈ (0.5187260624588579, 0.5187271656755446),
# 			  δn = (0, 0), from p = 0.5291454755978731
# ────────────────────────────────────────
# ────> Stopping reason:
# ──────> isnothing(next)           = false
# ──────> |ds| < dsminBisection     = false
# ──────> step >= maxBisectionSteps = true
# ──────> n_inversion >= nInversion = false
# ──────> eventlocated              = false
# ────> Leaving [Loc-Bif]
# !! Continuous user point at p ≈ 0.5187271656755446
# ───────────────────────────────────────────────────────
# Continuation Step 120
# Step size = 1.0000e-01
# Parameter U0 = 5.1873e-01 ⟶  5.2910e-01 [guess]
# ──> Step Converged in 2 Nonlinear Iteration(s)
# Parameter U0 = 5.1873e-01 ⟶  5.2915e-01
# ──> Computed 3 eigenvalues in 1 iterations, #unstable = 0
# Predictor:  Secant
# ──> Event values: (14.363922796793789, 7.385762956457764e-5, 0)
#               ──> (14.05998797556641, 0.023729536403461902, 0)
# ──> Event detected before p = 0.5291465970693068
# ────> Entering [Event], indicator of 2 last events = ((2, 0), (2, 0))
# ────> [Bisection] initial ds = 0.1
# ────> [Bisection] state.ds = -0.1
# ──> eve (initial) (14.363922796793789, 7.385762956457764e-5, 0) ──> (14.05998797556641, 0.023729536403461902, 0)
#
# ──> eigvals =
# -1.8783796740251546e-9 - 14.059988012584341im
# -1.8783796740251546e-9 + 14.059988012584341im
# -2.727800324271468 + 0.0im
#
# ────> eve (current) (14.05998797556641, 0.023729536403461902, 0) ──> (14.05998797556641, 0.023729536403461902, 0)
# ────> eigvals =
# -1.8783796740251546e-9 - 14.059988012584341im
# -1.8783796740251546e-9 + 14.059988012584341im
# -2.727800324271468 + 0.0im
# ────> 0 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.05, p = 0.5291465970693068, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5291465970693068), precision = 1.042E-02
# Predictor:  Secant
#
# ────> eve (current) (14.05998797556641, 0.023729536403461902, 0) ──> (14.211845792712106, 0.011292710995459594, 0)
# ────> eigvals =
# 2.4018786959345562e-11 - 14.211845792928802im
# 2.4018786959345562e-11 + 14.211845792928802im
# -3.071136443891328 + 0.0im
# ────> 1 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.025, p = 0.5239170353321526, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5239170353321526), precision = 5.190E-03
# Predictor:  Secant
#
# ────> eve (current) (14.211845792712106, 0.011292710995459594, 0) ──> (14.287857510430987, 0.005546483684265711, 0)
# ────> eigvals =
# 3.374234225361761e-11 - 14.287857510500531im
# 3.374234225361761e-11 + 14.287857510500531im
# -3.239932430453526 + 0.0im
# ────> 2 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.0125, p = 0.5213208088200331, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5213208088200331), precision = 2.594E-03
# Predictor:  Secant
#
# ────> eve (current) (14.287857510430987, 0.005546483684265711, 0) ──> (14.325875141625902, 0.002778164401960971, 0)
# ────> eigvals =
# -3.9968028886505635e-15 - 14.325875141626083im
# -3.9968028886505635e-15 + 14.325875141626083im
# -3.323739163219462 + 0.0im
# ────> 3 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.00625, p = 0.5200243314925995, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5200243314925995), precision = 1.297E-03
# Predictor:  Secant
#
# ────> eve (current) (14.325875141625902, 0.002778164401960971, 0) ──> (14.344886613376142, 0.0014187972127625154, 0)
# ────> eigvals =
# 1.7763568394002505e-15 - 14.344886613376158im
# 1.7763568394002505e-15 + 14.344886613376158im
# -3.3655086121955926 + 0.0im
# ────> 4 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.003125, p = 0.5193761721880846, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5193761721880846), precision = 6.490E-04
# Predictor:  Secant
#
# ────> eve (current) (14.344886613376142, 0.0014187972127625154, 0) ──> (14.354392968699749, 0.0007451525975384343, 0)
# ────> eigvals =
# -5.07900654866944e-9 - 14.354392970179747im
# -5.07900654866944e-9 + 14.354392970179747im
# -3.3863613850068766 + 0.0im
# ────> 5 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.0015625, p = 0.5190520750164568, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5190520750164568), precision = 3.249E-04
# Predictor:  Secant
#
# ────> eve (current) (14.354392968699749, 0.0007451525975384343, 0) ──> (14.359146296130245, 0.0004098199224954052, 0)
# ────> eigvals =
# -3.115707691847547e-10 - 14.359146296220693im
# -3.115707691847547e-10 + 14.359146296220693im
# -3.396779976490046 + 0.0im
# ────> 6 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.00078125, p = 0.5188900175123894, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5188900175123894), precision = 1.629E-04
# Predictor:  Secant
#
# ────> eve (current) (14.359146296130245, 0.0004098199224954052, 0) ──> (14.361522996274843, 0.00024252411885313657, 0)
# ────> eigvals =
# -1.9306556353626547e-11 - 14.361522996280437im
# -1.9306556353626547e-11 + 14.361522996280437im
# -3.401987340154361 + 0.0im
# ────> 7 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.000390625, p = 0.5188089860123105, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5188089860123105), precision = 8.182E-05
# Predictor:  Secant
#
# ────> eve (current) (14.361522996274843, 0.00024252411885313657, 0) ──> (14.362711355393284, 0.00015896851473062856, 0)
# ────> eigvals =
# -1.2247980407664727e-12 - 14.362711355393632im
# -1.2247980407664727e-12 + 14.362711355393632im
# -3.404590542229452 + 0.0im
# ────> 8 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -0.0001953125, p = 0.5187684695045148, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5187684695045148), precision = 4.130E-05
# Predictor:  Secant
#
# ────> eve (current) (14.362711355393284, 0.00015896851473062856, 0) ──> (14.363305537204491, 0.000117213748323651, 0)
# ────> eigvals =
# -9.059419880941277e-14 - 14.363305537204505im
# -9.059419880941277e-14 + 14.363305537204505im
# -3.40589202369811 + 0.0im
# ────> 9 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -9.765625e-5, p = 0.5187482110525721, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5187482110525721), precision = 2.105E-05
# Predictor:  Secant
#
# ────> eve (current) (14.363305537204491, 0.000117213748323651, 0) ──> (14.363602628671785, 9.63421193750924e-5, 0)
# ────> eigvals =
# 9.325873406851315e-15 - 14.363602628671789im
# 9.325873406851315e-15 + 14.363602628671789im
# -3.406542734584307 + 0.0im
# ────> 10 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -4.8828125e-5, p = 0.5187380817760275, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5187380817760275), precision = 1.092E-05
# Predictor:  Secant
#
# ────> eve (current) (14.363602628671785, 9.63421193750924e-5, 0) ──> (14.363751174405367, 8.590229962197188e-5, 0)
# ────> eigvals =
# 5.9040874189619785e-8 - 14.363751167754685im
# 5.9040874189619785e-8 + 14.363751167754685im
# -3.406868133351708 + 0.0im
# ────> 11 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -2.44140625e-5, p = 0.5187330171377574, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5187330171377574), precision = 5.851E-06
# Predictor:  Secant
#
# ────> eve (current) (14.363751174405367, 8.590229962197188e-5, 0) ──> (14.36382544751769, 8.069091408151319e-5, 0)
# ────> eigvals =
# 8.881784197001252e-15 - 14.363825447517687im
# 8.881784197001252e-15 + 14.363825447517687im
# -3.407030754700472 + 0.0im
# ────> 12 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -1.220703125e-5, p = 0.5187304847962457, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5187304847962457), precision = 3.319E-06
# Predictor:  Secant
#
# ────> eve (current) (14.36382544751769, 8.069091408151319e-5, 0) ──> (14.363862584073804, 7.808497110579904e-5, 0)
# ────> eigvals =
# -2.5833301053879154e-8 - 14.36386258698311im
# -2.5833301053879154e-8 + 14.36386258698311im
# -3.407112068080016 + 0.0im
# ────> 13 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -6.103515625e-6, p = 0.5187292186254916, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5187292186254916), precision = 2.053E-06
# Predictor:  Secant
#
# ────> eve (current) (14.363862584073804, 7.808497110579904e-5, 0) ──> (14.36388115235186, 7.678193705721453e-5, 0)
# ────> eigvals =
# -3.782815860553512e-8 - 14.363881156611837im
# -3.782815860553512e-8 + 14.363881156611837im
# -3.407152725446105 + 0.0im
# ────> 14 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -3.0517578125e-6, p = 0.5187285855401146, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5187285855401146), precision = 1.420E-06
# Predictor:  Secant
#
# ────> eve (current) (14.36388115235186, 7.678193705721453e-5, 0) ──> (14.363890436490887, 7.613040440369867e-5, 0)
# ────> eigvals =
# -4.359514216289995e-8 - 14.363890441400182im
# -4.359514216289995e-8 + 14.363890441400182im
# -3.4071730542982297 + 0.0im
# ────> 15 - [Bisection] (n1, n_current, n2) = ((2, 0), (2, 0), (2, 0))
# 			ds = -1.52587890625e-6, p = 0.5187282689974261, #reverse = 0
# ────> event ∈ (0.5187271656755446, 0.5187282689974261), precision = 1.103E-06
# ────> Found at p = 0.5187282689974261 ∈ (0.5187271656755446, 0.5187282689974261),
# 			  δn = (0, 0), from p = 0.5291465970693068
# Excessive output truncated after 524531 bytes.

# %%
hp_codim2_1
# Out:
#  ┌─ Curve type: HopfCont
#  ├─ Number of points: 214
#  ├─ Type of vectors: Vector{Float64}
#  ├─ Parameter U0 starts at 0.1798874870608784, ends at 0.55
#  ├─ Algo: PALC
#  └─ Special points:
#
# If `br` is the name of the branch,
# ind_ev = index of the bifurcating eigenvalue e.g. `br.eig[idx].eigenvals[ind_ev]`
#
# - #  1, endpoint at U0 ≈ +0.17988749,                                                                     step =   0
# - #  2,       bt at U0 ≈ +0.17988749 ∈ (+0.17988744, +0.17988749), |δp|=5e-08, [converged], δ = ( 0,  0), step =   0, eigenelements in eig[  1], ind_ev =   0
# - #  3,       gh at U0 ≈ +0.22163355 ∈ (+0.22163355, +0.22163758), |δp|=4e-06, [converged], δ = ( 0,  0), step =  34, eigenelements in eig[ 35], ind_ev =   0
# - #  4,       gh at U0 ≈ +0.51870852 ∈ (+0.51860149, +0.51870852), |δp|=1e-04, [converged], δ = ( 0,  0), step = 159, eigenelements in eig[160], ind_ev =   0
# - #  5,       gh at U0 ≈ +0.51869137 ∈ (+0.51869092, +0.51869137), |δp|=4e-07, [converged], δ = ( 0,  0), step = 160, eigenelements in eig[161], ind_ev =   0
# - #  6,       gh at U0 ≈ +0.51869144 ∈ (+0.51869051, +0.51869144), |δp|=9e-07, [converged], δ = ( 0,  0), step = 161, eigenelements in eig[162], ind_ev =   0
# - #  7,       gh at U0 ≈ +0.51869156 ∈ (+0.51869057, +0.51869156), |δp|=1e-06, [converged], δ = ( 0,  0), step = 162, eigenelements in eig[163], ind_ev =   0
# - #  8,       gh at U0 ≈ +0.51869172 ∈ (+0.51869068, +0.51869172), |δp|=1e-06, [converged], δ = ( 0,  0), step = 163, eigenelements in eig[164], ind_ev =   0
# - #  9,       gh at U0 ≈ +0.51869193 ∈ (+0.51869083, +0.51869193), |δp|=1e-06, [converged], δ = ( 0,  0), step = 164, eigenelements in eig[165], ind_ev =   0
# - # 10,       gh at U0 ≈ +0.51869221 ∈ (+0.51869105, +0.51869221), |δp|=1e-06, [converged], δ = ( 0,  0), step = 165, eigenelements in eig[166], ind_ev =   0
# - # 11,       gh at U0 ≈ +0.51869135 ∈ (+0.51868891, +0.51869135), |δp|=2e-06, [converged], δ = ( 0,  0), step = 166, eigenelements in eig[167], ind_ev =   0
# - # 12,       gh at U0 ≈ +0.51869302 ∈ (+0.51869049, +0.51869302), |δp|=3e-06, [converged], δ = ( 0,  0), step = 167, eigenelements in eig[168], ind_ev =   0
# - # 13,       gh at U0 ≈ +0.51869411 ∈ (+0.51869302, +0.51869411), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 168, eigenelements in eig[169], ind_ev =   0
# - # 14,       gh at U0 ≈ +0.51869521 ∈ (+0.51869411, +0.51869521), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 169, eigenelements in eig[170], ind_ev =   0
# - # 15,       gh at U0 ≈ +0.51869632 ∈ (+0.51869521, +0.51869632), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 170, eigenelements in eig[171], ind_ev =   0
# - # 16,       gh at U0 ≈ +0.51869742 ∈ (+0.51869632, +0.51869742), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 171, eigenelements in eig[172], ind_ev =   0
# - # 17,       gh at U0 ≈ +0.51869852 ∈ (+0.51869742, +0.51869852), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 172, eigenelements in eig[173], ind_ev =   0
# - # 18,       gh at U0 ≈ +0.51869962 ∈ (+0.51869852, +0.51869962), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 173, eigenelements in eig[174], ind_ev =   0
# - # 19,       gh at U0 ≈ +0.51870072 ∈ (+0.51869962, +0.51870072), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 174, eigenelements in eig[175], ind_ev =   0
# - # 20,       gh at U0 ≈ +0.51870182 ∈ (+0.51870072, +0.51870182), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 175, eigenelements in eig[176], ind_ev =   0
# - # 21,       gh at U0 ≈ +0.51870292 ∈ (+0.51870182, +0.51870292), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 176, eigenelements in eig[177], ind_ev =   0
# - # 22,       gh at U0 ≈ +0.51870402 ∈ (+0.51870292, +0.51870402), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 177, eigenelements in eig[178], ind_ev =   0
# - # 23,       gh at U0 ≈ +0.51870512 ∈ (+0.51870402, +0.51870512), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 178, eigenelements in eig[179], ind_ev =   0
# - # 24,       gh at U0 ≈ +0.51870622 ∈ (+0.51870512, +0.51870622), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 179, eigenelements in eig[180], ind_ev =   0
# - # 25,       gh at U0 ≈ +0.51870732 ∈ (+0.51870622, +0.51870732), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 180, eigenelements in eig[181], ind_ev =   0
# - # 26,       gh at U0 ≈ +0.51870843 ∈ (+0.51870732, +0.51870843), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 181, eigenelements in eig[182], ind_ev =   0
# - # 27,       gh at U0 ≈ +0.51870953 ∈ (+0.51870843, +0.51870953), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 182, eigenelements in eig[183], ind_ev =   0
# - # 28,       gh at U0 ≈ +0.51871063 ∈ (+0.51870953, +0.51871063), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 183, eigenelements in eig[184], ind_ev =   0
# - # 29,       gh at U0 ≈ +0.51871173 ∈ (+0.51871063, +0.51871173), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 184, eigenelements in eig[185], ind_ev =   0
# - # 30,       gh at U0 ≈ +0.51871283 ∈ (+0.51871173, +0.51871283), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 185, eigenelements in eig[186], ind_ev =   0
# - # 31,       gh at U0 ≈ +0.51871393 ∈ (+0.51871283, +0.51871393), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 186, eigenelements in eig[187], ind_ev =   0
# - # 32,       gh at U0 ≈ +0.51871504 ∈ (+0.51871393, +0.51871504), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 187, eigenelements in eig[188], ind_ev =   0
# - # 33,       gh at U0 ≈ +0.51871614 ∈ (+0.51871504, +0.51871614), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 188, eigenelements in eig[189], ind_ev =   0
# - # 34,       gh at U0 ≈ +0.51871724 ∈ (+0.51871614, +0.51871724), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 189, eigenelements in eig[190], ind_ev =   0
# - # 35,       gh at U0 ≈ +0.51871834 ∈ (+0.51871724, +0.51871834), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 190, eigenelements in eig[191], ind_ev =   0
# - # 36,       gh at U0 ≈ +0.51871945 ∈ (+0.51871834, +0.51871945), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 191, eigenelements in eig[192], ind_ev =   0
# - # 37,       gh at U0 ≈ +0.51872055 ∈ (+0.51871945, +0.51872055), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 192, eigenelements in eig[193], ind_ev =   0
# - # 38,       gh at U0 ≈ +0.51872165 ∈ (+0.51872055, +0.51872165), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 193, eigenelements in eig[194], ind_ev =   0
# - # 39,       gh at U0 ≈ +0.51872275 ∈ (+0.51872165, +0.51872275), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 194, eigenelements in eig[195], ind_ev =   0
# - # 40,       gh at U0 ≈ +0.51872386 ∈ (+0.51872275, +0.51872386), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 195, eigenelements in eig[196], ind_ev =   0
# - # 41,       gh at U0 ≈ +0.51872496 ∈ (+0.51872386, +0.51872496), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 196, eigenelements in eig[197], ind_ev =   0
# - # 42,       gh at U0 ≈ +0.51872606 ∈ (+0.51872496, +0.51872606), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 197, eigenelements in eig[198], ind_ev =   0
# - # 43,       gh at U0 ≈ +0.51872717 ∈ (+0.51872606, +0.51872717), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 198, eigenelements in eig[199], ind_ev =   0
# - # 44,       gh at U0 ≈ +0.51872827 ∈ (+0.51872717, +0.51872827), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 199, eigenelements in eig[200], ind_ev =   0
# - # 45,       gh at U0 ≈ +0.51872937 ∈ (+0.51872827, +0.51872937), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 200, eigenelements in eig[201], ind_ev =   0
# - # 46,       gh at U0 ≈ +0.51873048 ∈ (+0.51872937, +0.51873048), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 201, eigenelements in eig[202], ind_ev =   0
# - # 47,       gh at U0 ≈ +0.51873158 ∈ (+0.51873048, +0.51873158), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 202, eigenelements in eig[203], ind_ev =   0
# - # 48,       gh at U0 ≈ +0.51873268 ∈ (+0.51873158, +0.51873268), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 203, eigenelements in eig[204], ind_ev =   0
# - # 49,       gh at U0 ≈ +0.51873379 ∈ (+0.51873268, +0.51873379), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 204, eigenelements in eig[205], ind_ev =   0
# - # 50,       gh at U0 ≈ +0.51873489 ∈ (+0.51873379, +0.51873489), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 205, eigenelements in eig[206], ind_ev =   0
# - # 51,       gh at U0 ≈ +0.51873600 ∈ (+0.51873489, +0.51873600), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 206, eigenelements in eig[207], ind_ev =   0
# - # 52,       gh at U0 ≈ +0.51873710 ∈ (+0.51873600, +0.51873710), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 207, eigenelements in eig[208], ind_ev =   0
# - # 53,       gh at U0 ≈ +0.51873820 ∈ (+0.51873710, +0.51873820), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 208, eigenelements in eig[209], ind_ev =   0
# - # 54,       gh at U0 ≈ +0.51873931 ∈ (+0.51873820, +0.51873931), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 209, eigenelements in eig[210], ind_ev =   0
# - # 55,       gh at U0 ≈ +0.51874041 ∈ (+0.51873931, +0.51874041), |δp|=1e-06, [    guess], δ = ( 0,  0), step = 210, eigenelements in eig[211], ind_ev =   0
# - # 56, endpoint at U0 ≈ +0.55000000,                                                                     step = 213

# %%
hp_codim2_1[35]
# Out:
# (I0 = -1.712846288235767, U0 = 0.22163354833461535, ωₕ = 10.218023776753865, l1 = 0.00019210613553760636 + 0.9709559404215089im, BT = 10.218023776753865, GH = 0.00019210613553760636, x = 7.691841580090067, param = 0.22163354833461535, itnewton = 2, itlinear = 4, ds = -0.1, n_unstable = 0, n_imag = 0, stable = true, step = 34, eigenvals = ComplexF64[-2.1087650292628268e-8 - 10.218023721367148im, -2.1087650292628268e-8 + 10.218023721367148im, -0.4535777434351986 + 0.0im], eigenvecs = ComplexF64[-0.9997853500528465 - 0.0im -0.9997853500528465 + 0.0im 0.9654764021378872 + 0.0im; 0.01744756834163887 + 0.010764432236282262im 0.01744756834163887 - 0.010764432236282262im -0.026136904846498648 + 0.0im; -0.0014957600985266272 + 0.0025934299737738805im -0.0014957600985266272 - 0.0025934299737738805im 0.25917596169383766 + 0.0im])

# %%
hp_codim2_1.sol[35]
# Out:
# (x = [7.636193739951251, 0.7569188314965775, 0.5291936712184264, -1.712846288235767, 10.218023776753865], p = 0.22163354833461535, step = 34)

# %%
hp_codim2_1[1]
# Out:
# (I0 = -1.3029892787649975, U0 = 0.1798874870608784, ωₕ = -0.004099273561106481, l1 = 289.19292477792624 - 5.907819273647964e7im, BT = -0.004099273561106481, GH = 289.19292477792624, x = 5.150659211407544, param = 0.1798874870608784, itnewton = 2, itlinear = 4, ds = -0.1, n_unstable = 0, n_imag = 0, stable = true, step = 0, eigenvals = ComplexF64[-2.9036862215158724e-7 - 0.075219043021921im, -2.9036862215158724e-7 + 0.075219043021921im, -0.3030394313589299 + 0.0im], eigenvecs = ComplexF64[0.9974623108269425 - 0.0im 0.9974623108269425 + 0.0im -0.0004339308830098702 + 0.0im; -0.027105243591701363 - 0.00013645812571871533im -0.027105243591701363 + 0.00013645812571871533im 1.2037191804263925e-5 + 0.0im; -0.06381514169548913 - 0.016181882436080857im -0.06381514169548913 + 0.016181882436080857im -0.999999905779543 + 0.0im])

# %%
sn_codim2_1 = continuation(hp_codim2_1, 2,
    ContinuationPar(opts_con, pMin = 0.0, pMax = 0.4,
        ds = 0.001, dsmax = 0.1, dsmin = 1e-5),
    # detection of codim 2 bifurcations with bisection
    detectCodim2Bifurcation = 2,
    # tell to start the Hopf problem using eigen elements: compute left eigenvector
    startWithEigen = true,
    # we update the Hopf problem at every continuation step
    updateMinAugEveryStep = 1,
    # compute both sides of the initial condition
    bothside = true,
    verbosity = 3
    )
# Out:
#  ┌─ Curve type: FoldCont from BogdanovTakens bifurcation point.
#  ├─ Number of points: 91
#  ├─ Type of vectors: Vector{Float64}
#  ├─ Parameter U0 starts at 0.3901567903532747, ends at 0.4
#  ├─ Algo: PALC
#  └─ Special points:
#
# If `br` is the name of the branch,
# ind_ev = index of the bifurcating eigenvalue e.g. `br.eig[idx].eigenvals[ind_ev]`
#
# - #  1, endpoint at U0 ≈ +0.40000000,                                                                     step =   0
# - #  2,     cusp at U0 ≈ +0.16172428 ∈ (+0.16172428, +0.16172428), |δp|=2e-11, [   guessL], δ = ( 0,  0), step =  16, eigenelements in eig[ 17], ind_ev =   0
# - #  3,       bt at U0 ≈ +0.17988639 ∈ (+0.17988639, +0.17988648), |δp|=9e-08, [converged], δ = ( 0,  0), step =  44, eigenelements in eig[ 45], ind_ev =   0
# - #  4, endpoint at U0 ≈ +0.40000000,                                                                     step =  90

# %%
sn_codim2_1[16]
# Out:
# (I0 = -1.1200596482046454, U0 = 0.16193284544777642, BT = 0.010625546204470785, CP = -0.004821757392595041, ZH = 0, x = 3.835511328120678, param = 0.16193284544777642, itnewton = 2, itlinear = 4, ds = -0.04565297391797413, n_unstable = 0, n_imag = 0, stable = true, step = 15, eigenvals = ComplexF64[-1.0882573271350782e-11 + 0.0im, -0.3030302971660217 + 0.0im, -3.8155773300322147 + 0.0im], eigenvecs = ComplexF64[-0.9989250598818357 + 0.0im -5.229967999754139e-7 + 0.0im -0.9992070420046493 + 0.0im; 0.028940671538677718 + 0.0im 1.5467107966425255e-8 + 0.0im 0.03958572450297103 + 0.0im; 0.03620997474400421 + 0.0im 0.9999999999998631 + 0.0im -0.004272894088804965 + 0.0im])

# %%
plot(hp_codim2_1, sn_codim2_1, branchlabel = ["Fold", "Hopf"])

# %%
jldsave("hp_codim2_1.jld2"; hp_codim2_1.I0, hp_codim2_1.U0)
#jldsave("sn_codim2_1.jld2"; sn_codim2_1.I0, sn_codim2_1.U0)
