# %%
using Pkg
Pkg.activate("C:\\Users\\Alex\\Desktop\\dynamical-systems\\env\\integrate\\")
# Out:
#   Activating project at `C:\Users\Alex\Desktop\dynamical-systems\env\integrate`

# %%
using JLD, CairoMakie, GLMakie

# %%
cd("C:\\Users\\Alex\\Desktop\\dynamical-systems\\Tsodyks Markram\\Levanova\\3 набор параметров\\Сопоставление с матконт\\файлы matlab")
I0_hom = load("I0_hom.jld")["data"]
u0_hom = load("u0_hom.jld")["data"]
I0_hom = I0_hom[:]
u0_hom = u0_hom[:]
# Out:
# 190-element Vector{Float64}:
#  0.2650000065028337
#  0.26499932107376073
#  0.2649984325607588
#  0.2649972818197833
#  0.26499584494042694
#  0.2649939223198975
#  0.2649914443936827
#  0.2649882385389163
#  0.2649841620110173
#  0.26497897281231597
#  0.26497296425978323
#  0.26496698325959905
#  0.26496121160466946
#  ⋮
#  0.2650179834182692
#  0.26501754894770313
#  0.26501710782286764
#  0.26501689299576325
#  0.26501644006372954
#  0.26501598185622055
#  0.2650156730752557
#  0.2650152105713847
#  0.26501498386554534
#  0.2650149584443961
#  0.26501493634066164
#  0.26501493237457635

# %%
CairoMakie.activate!()

# %%
cd("C:\\Users\\Alex\\Desktop\\dynamical-systems\\Tsodyks Markram\\Levanova\\3 набор параметров\\Сопоставление с матконт\\Карты спектров\\")
Λs = load("LSs_350_350_tauD_article2_slice.jld")["data"];

# %%
I0range = range( -1.5, -2.0,  length = 350 )
U0range = range( 0.25,  0.55, length = 350 )

index = 1
I0st, I0ed = 1, 350
U0st, U0ed = 1, 330
absmax = maximum(abs.(Λs[I0st:I0ed, U0st:U0ed, index]))

mn, mx =  -absmax, absmax
GLMakie.activate!()
f = Figure()

ax1 = Axis(f[1, 1], xlabel = L"I_0",ylabel = L"u_0", xlabelsize = 50, ylabelsize = 50,
            xticklabelsize = 35, yticklabelsize = 35,
            xgridvisible  = false, ygridvisible = false)

hm = heatmap!(ax1, I0range[I0st:I0ed], U0range[U0st:U0ed], Λs[I0st:I0ed, U0st:U0ed, index], colormap = :seismic,
                 colorrange = (mn, mx))

display(f)
# Out:
# GLMakie.Screen(...)

# %%
f = Figure()
ax1 = Axis(f[1, 1])
lines!(I0_hom[1:end], u0_hom[1:end], linewidth = 1.5, color = :black)
GLMakie.activate!()
display(f)
# Out:
# GLMakie.Screen(...)

# %%
GLMakie.activate!()
display(f)
# Out:
# GLMakie.Screen(...)

# %%
index = 190
I0_hom[index], u0_hom[index]
# Out:
# (-1.7064319914455124, 0.26501493237457635)

# %%
cd("C:\\Users\\Alex\\Desktop\\dynamical-systems\\Tsodyks Markram\\Levanova\\3 набор параметров\\Сопоставление с матконт\\Карты спектров\\")
Λs = load("LSs_350_350_tauD_article2.jld")["data"];

# %%
I0range = range( -0.5, -2.0,  length = 350 )
U0range = range( 0.22,  0.55, length = 350 )

index = 1
I0st, I0ed = 1, 350
U0st, U0ed = 1, 350
absmax = maximum(abs.(Λs[I0st:I0ed, U0st:U0ed, index]))

mn, mx =  -absmax, absmax
f = Figure()

ax1 = Axis(f[1, 1], xlabel = L"I_0",ylabel = L"u_0", xlabelsize = 50, ylabelsize = 50,
            xticklabelsize = 35, yticklabelsize = 35,
            xgridvisible  = false, ygridvisible = false)

hm = heatmap!(ax1, I0range[I0st:I0ed], U0range[U0st:U0ed], Λs[I0st:I0ed, U0st:U0ed, index], colormap = :seismic,
                 colorrange = (mn, mx))

lines!(I0_hom[1:end], u0_hom[1:end], linewidth = 1.0, color = :black)

display(f)
# Out:
# CairoMakie.Screen{IMAGE}
