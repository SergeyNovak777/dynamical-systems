# %%
pathtorepo = "C:\\Users\\Alex\\Desktop\\"

using Pkg
Pkg.activate(pathtorepo * "dynamical-systems\\env\\integrate\\")

using JLD, CairoMakie
# Out:
#   Activating project at `C:\Users\Alex\Desktop\dynamical-systems\env\integrate`

# %%
path = "C:\\Users\\Alex\\YandexDisk\\Science\\TM\\Levanova\\3 набор параметров\\Map modes\\"
modes = load(path*"modes.jld")["data"];

# %%
I0range = range( -1.40, -1.709, length = 201 )
U0range = range( 0.3,  0.47, length = 201)

f = Figure()
ax1 = Axis(f[1, 1], xlabel = L"$I_0$ $(Hz)$",ylabel = L"$U_0$ $(arb. unit)$", xlabelsize = 45, ylabelsize = 45,
            xticklabelsize = 30, yticklabelsize = 30,
            xgridvisible  = false, ygridvisible = false, xticks = [-1.7, -1.6, -1.5, -1.42])

hm = heatmap!(ax1, I0range, U0range, modes,
                colormap = :jet1)
                
f

# %%
save("map_modes_fix_labels.eps", f)
# Out:
# CairoMakie.Screen{EPS}
