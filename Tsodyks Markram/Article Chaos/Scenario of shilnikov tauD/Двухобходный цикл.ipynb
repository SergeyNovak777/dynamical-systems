# %%
if Sys.iswindows()
    username = "Alex"
    pathtorepo = "C:\\Users\\" *username *  "\\Desktop\\"
    using Pkg
    Pkg.activate(pathtorepo * "dynamical-systems\\env\\integrate\\")
else
    username = "sergey"
    pathtorepo = "/home/" *username *"/work/repo/dynamical-systems"
    using Pkg
    Pkg.activate(pathtorepo * "/env/integrate/")
    include("/home/sergey/work/repo/dynamical-systems/system.jl")
end
# Out:
#   Activating project at `~/work/repo/dynamical-systems/env/integrate`
# jac_FHN (generic function with 1 method)

# %%
using StaticArrays, DifferentialEquations, DynamicalSystems
E, x, y  = 0..40, 0..1,  0..1
box = E × x × y
using CairoMakie

# %%
const τ = 0.013;  const τD = 0.07993;  const τy = 3.3;  const J = 3.07;  const β = 0.300
const xthr = 0.75; const ythr = 0.4
const α = 1.58; const ΔU0 = 0.305;

# %%
time = 500; tt = 1000; tstep = 0.001
integ_set = (alg = Vern9(), adaptive = false, dt = tstep)
# Out:
# (alg = Vern9(; stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false), lazy = true,), adaptive = false, dt = 0.001)

# %%
I0 = -1.66; U0 = 0.265;
p = [α, τ, τD, τy, J, xthr, ythr, U0, ΔU0, β, I0]
u0 = [8.638526524981895, 0.7320692774159767, 0.40718205935401675]
println("last point trajectory:$u0")
# Out:
# last point trajectory:[8.638526524981895, 0.7320692774159767, 0.40718205935401675]

# %%
ds = CoupledODEs(TM, u0, p, diffeq = integ_set)
# Out:
# 3-dimensional CoupledODEs
#  deterministic: true
#  discrete time: false
#  in-place:      false
#  dynamic rule:  TM
#  ODE solver:    Vern9
#  ODE kwargs:    (adaptive = false, dt = 0.001)
#  parameters:    [1.58, 0.013, 0.07993, 3.3, 3.07, 0.75, 0.4, 0.265, 0.305, 0.3, -1.66]
#  time:          0.0
#  state:         [8.638526524981895, 0.7320692774159767, 0.40718205935401675]

# %%
tr, trange = trajectory(ds, time; Δt = integ_set.dt, Ttr = tt);

# %%
fp, ei, _ = fixedpoints(ds, box, jacob_TM_)
# Out:
# (3-dimensional StateSpaceSet{Float64} with 1 points, Vector{ComplexF64}[[-6.580400240639088 + 0.0im, 2.0002994849349376 - 14.050848080566963im, 2.0002994849349376 + 14.050848080566963im]], Bool[0])

# %%
lb_size = 35; tck_size = 30;

# %%
ts, tf = 99000, 100000
indexx,indexy,indexz = 2, 3, 1

f = Figure(size = (900, 600))
axis3 = Axis3(f[1, 1], xlabel = "x", ylabel = "y", zlabel = "E",
                xlabelsize = lb_size, ylabelsize = lb_size, zlabelsize = lb_size,
                xticklabelsize = tck_size, yticklabelsize = tck_size, zticklabelsize = tck_size,
                xgridvisible = false, ygridvisible = false, zgridvisible = false,
                yticks = [0.440, 0.450, 0.460])
lines!(axis3, tr[ts:tf, indexx], tr[ts:tf, indexy], tr[ts:tf, indexz], linewidth = 2.5, color = :black)

scatter!(fp[1][indexx], fp[1][indexy], fp[1][indexz], color = :red, markersize = 15.0)
text!(fp[1][indexx], fp[1][indexy], fp[1][indexz], text = L"O_1", fontsize = 50, color = :black, align = (:left, :bottom))

display(f)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
cd("/home/sergey/MEGA/dynamical-systems/Tsodyks Markram/images")
save("2-limit_cycle.pdf", f)
# Out:
# CairoMakie.Screen{PDF}
