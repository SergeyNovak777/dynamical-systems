# %%
using Pkg
Pkg.activate("C:\\Users\\Alex\\Desktop\\repo\\2612\\0903\\dynamical-systems\\env\\integrate\\")
using JLD, CairoMakie
# Out:
#   Activating project at `C:\Users\Alex\Desktop\repo\2612\0903\dynamical-systems\env\integrate`

# %%
path_lse = "C:\\Users\\Alex\\Desktop\\repo\\2612\\0903\\dynamical-systems\\Tsodyks Markram\\Levanova\\3 набор параметров\\Спектр Ляпуновских показателей"
path_bf = "C:\\Users\\Alex\\Desktop\\repo\\2612\\0903\\dynamical-systems\\Tsodyks Markram\\Levanova\\3 набор параметров\\Бифуркации";

# %%
LSE = load(path_lse*"\\LSE_3k_dots_U0 = 0.35.jld")["data"];
bf = load(path_bf*"\\bif_dia_U0=0.35_3k_dots.jld")["data"];

# %%
I0range = range( -1.4, -1.709, length = 3001 )
# Out:
# -1.4:-0.000103:-1.709

# %%
size_marker = 3.0
f = Figure(resolution = (1300, 600))

ax_bf = Axis(f[1,1]; ylabel = L"E", xlabelsize = 35, ylabelsize = 35,
            xticklabelsize = 30, yticklabelsize = 30, xgridvisible = false, ygridvisible = false)
ax_lse = Axis(f[2, 1]; xlabel = L"I_0", ylabel = L"\Lambda _{1,2,3}", xlabelsize = 35, ylabelsize = 35,
            xticklabelsize = 30, yticklabelsize = 30, xgridvisible = false, ygridvisible = false)

for (j, p) in enumerate(I0range)
    scatter!(ax_bf, fill(p, length(bf[:][j])), bf[:][j]; color = ("black", 0.5), markersize = size_marker)
end

lines!(ax_lse, I0range, LSE[:, 1], linewidth = size_marker, color = :red)
lines!(ax_lse, I0range, LSE[:, 2], linewidth = size_marker, color = :green)
lines!(ax_lse, I0range, LSE[:, 3], linewidth = size_marker, color = :blue)

f

# %%
save("bf_LSE_U0=0.35.eps", f)
# Out:
# CairoMakie.Screen{EPS}
