# %%
pathtorepo = "C:\\Users\\Alex\\Desktop\\"

using Pkg
Pkg.activate(pathtorepo * "dynamical-systems\\env\\integrate\\")
# Out:
#   Activating project at `C:\Users\Alex\Desktop\dynamical-systems\env\integrate`

# %%
using JLD, CairoMakie

# %%
path = pathtorepo * "dynamical-systems\\Tsodyks Markram\\Levanova\\3 набор параметров\\"
# Out:
# "C:\\Users\\Alex\\Desktop\\dynamical-systems\\Tsodyks Markram\\Levanova\\3 набор параметров\\"

# %%
cd(path*"\\Сопоставление с матконт")

# %%
output = load("Modes_200x200.jld")["data"]
I0range = range( -0.5, -2.0,  length = 200 )
U0range = range( 0.22,  0.55, length = 200 )
# Out:
# 0.22:0.0016582914572864321:0.55

# %%
f = Figure()
ax1 = Axis(f[1, 1], xlabel = L"I0",ylabel = L"U0", xlabelsize = 50, ylabelsize = 50,
            xticklabelsize = 35, yticklabelsize = 35,
            xgridvisible  = false, ygridvisible = false)

hm = heatmap!(ax1, I0range, U0range, output,
                colormap = :jet1)
#Colorbar(f[1, 2], hm, ticklabelsize = 35)
f
