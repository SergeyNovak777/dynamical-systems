# %%
using StaticArrays, DifferentialEquations, DynamicalSystems, CairoMakie

# %%
function TM(u, p, t)

    U(y) = U0 + ΔU0 / ( 1 + exp( -50*(y-ythr) ) )
    σ(x) = 1 / ( 1 + exp( -20*(x-xthr) ) )

    E, x, y = u
    α, τ, τD, τy, J, xthr, ythr, U0, ΔU0, β, I0 = p

    du1 = (-E + α * log( 1 + exp( (J * U(y) * x * E + I0  ) / (α) ) ) ) / τ
    du2 = (1-x)/τD - U(y)*x*E
    du3 = (-y)/τy+β*σ(x)

    return SVector(du1, du2, du3)
end
# Out:
# TM (generic function with 1 method)

# %%
function count_floats(a, b)
    count = 0
    if a > b
        a, b = b, a
    end
    while a < b
        a = nextfloat(a)
        count += 1
    end
    return count
end
# Out:
# count_floats (generic function with 1 method)

# %%
t = 500.0; tt = 200.0; tstep = 0.001
trange = range(0.0, t, step = tstep);

# %%
integ_set = (alg = RK4(), adaptive = false, dt = tstep);

# %%
const τ = 0.013;  const τD = 0.080;  const τy = 3.3;  const J = 3.07;  const β = 0.300
const xthr = 0.75; const ythr = 0.4
const α = 1.58;  const U0 = 0.3;  const ΔU0 = 0.305;

# %%
I0 = -1.8
p =  [α, τ, τD, τy, J, xthr, ythr, U0, ΔU0, β, I0]
u0 = [8.39353, 0.73803, 0.429055];

# %%
ds = ContinuousDynamicalSystem(TM, u0, p)
# Out:
# 3-dimensional continuous dynamical system
#  state:       [8.39353, 0.73803, 0.429055]
#  rule f:      TM
#  in-place?    false
#  jacobian:    ForwardDiff
#  parameters:  [1.58, 0.013, 0.08, 3.3, 3.07, 0.75, 0.4, 0.3, 0.305, 0.3, -1.8]

# %%
I0range = range( -1.8, -1.87036, length = 501 )

idx_control_parameter = 11

idx_fix = 1; fixed_value = 15
surface = (idx_fix, fixed_value)
setting_root = (xrtol = 1e-13, atol = 1e-13);

# %%
I0range
# Out:
# -1.8:-0.00014072:-1.87036

# %%
count_floats(Float32(I0range[1]), Float32(I0range[end]))
# Out:
# 590223

# %%
idx_save = 2
output = produce_orbitdiagram(ds, surface, idx_save,
                        idx_control_parameter, I0range;
                        tfinal = t, Ttr = tt,
                        printparams = true,
                        diffeq = integ_set, rootkw = setting_root
                        );
# Out:
# parameter = -1.8
# parameter = -1.80014072
# parameter = -1.80028144
# parameter = -1.80042216
# parameter = -1.80056288
# parameter = -1.8007036
# parameter = -1.80084432
# parameter = -1.80098504
# parameter = -1.80112576
# parameter = -1.80126648
# parameter = -1.8014072
# parameter = -1.80154792
# parameter = -1.80168864
# parameter = -1.80182936
# parameter = -1.80197008
# parameter = -1.8021108
# parameter = -1.80225152
# parameter = -1.80239224
# parameter = -1.80253296
# parameter = -1.80267368
# parameter = -1.8028144
# parameter = -1.80295512
# parameter = -1.80309584
# parameter = -1.80323656
# parameter = -1.80337728
# parameter = -1.803518
# parameter = -1.80365872
# parameter = -1.80379944
# parameter = -1.80394016
# parameter = -1.80408088
# parameter = -1.8042216
# parameter = -1.80436232
# parameter = -1.80450304
# parameter = -1.80464376
# parameter = -1.80478448
# parameter = -1.8049252
# parameter = -1.80506592
# parameter = -1.80520664
# parameter = -1.80534736
# parameter = -1.80548808
# parameter = -1.8056288
# parameter = -1.80576952
# parameter = -1.80591024
# parameter = -1.80605096
# parameter = -1.80619168
# parameter = -1.8063324
# parameter = -1.80647312
# parameter = -1.80661384
# parameter = -1.80675456
# parameter = -1.80689528
# parameter = -1.807036
# parameter = -1.80717672
# parameter = -1.80731744
# parameter = -1.80745816
# parameter = -1.80759888
# parameter = -1.8077396
# parameter = -1.80788032
# parameter = -1.80802104
# parameter = -1.80816176
# parameter = -1.80830248
# parameter = -1.8084432
# parameter = -1.80858392
# parameter = -1.80872464
# parameter = -1.80886536
# parameter = -1.80900608
# parameter = -1.8091468
# parameter = -1.80928752
# parameter = -1.80942824
# parameter = -1.80956896
# parameter = -1.80970968
# parameter = -1.8098504
# parameter = -1.80999112
# parameter = -1.81013184
# parameter = -1.81027256
# parameter = -1.81041328
# parameter = -1.810554
# parameter = -1.81069472
# parameter = -1.81083544
# parameter = -1.81097616
# parameter = -1.81111688
# parameter = -1.8112576
# parameter = -1.81139832
# parameter = -1.81153904
# parameter = -1.81167976
# parameter = -1.81182048
# parameter = -1.8119612
# parameter = -1.81210192
# parameter = -1.81224264
# parameter = -1.81238336
# parameter = -1.81252408
# parameter = -1.8126648
# parameter = -1.81280552
# parameter = -1.81294624
# parameter = -1.81308696
# parameter = -1.81322768
# parameter = -1.8133684
# parameter = -1.81350912
# parameter = -1.81364984
# parameter = -1.81379056
# parameter = -1.81393128
# parameter = -1.814072
# parameter = -1.81421272
# parameter = -1.81435344
# parameter = -1.81449416
# parameter = -1.81463488
# parameter = -1.8147756
# parameter = -1.81491632
# parameter = -1.81505704
# parameter = -1.81519776
# parameter = -1.81533848
# parameter = -1.8154792
# parameter = -1.81561992
# parameter = -1.81576064
# parameter = -1.81590136
# parameter = -1.81604208
# parameter = -1.8161828
# parameter = -1.81632352
# parameter = -1.81646424
# parameter = -1.81660496
# parameter = -1.81674568
# parameter = -1.8168864
# parameter = -1.81702712
# parameter = -1.81716784
# parameter = -1.81730856
# parameter = -1.81744928
# parameter = -1.81759
# parameter = -1.81773072
# parameter = -1.81787144
# parameter = -1.81801216
# parameter = -1.81815288
# parameter = -1.8182936
# parameter = -1.81843432
# parameter = -1.81857504
# parameter = -1.81871576
# parameter = -1.81885648
# parameter = -1.8189972
# parameter = -1.81913792
# parameter = -1.81927864
# parameter = -1.81941936
# parameter = -1.81956008
# parameter = -1.8197008
# parameter = -1.81984152
# parameter = -1.81998224
# parameter = -1.82012296
# parameter = -1.82026368
# parameter = -1.8204044
# parameter = -1.82054512
# parameter = -1.82068584
# parameter = -1.82082656
# parameter = -1.82096728
# parameter = -1.821108
# parameter = -1.82124872
# parameter = -1.82138944
# parameter = -1.82153016
# parameter = -1.82167088
# parameter = -1.8218116
# parameter = -1.82195232
# parameter = -1.82209304
# parameter = -1.82223376
# parameter = -1.82237448
# parameter = -1.8225152
# parameter = -1.82265592
# parameter = -1.82279664
# parameter = -1.82293736
# parameter = -1.82307808
# parameter = -1.8232188
# parameter = -1.82335952
# parameter = -1.82350024
# parameter = -1.82364096
# parameter = -1.82378168
# parameter = -1.8239224
# parameter = -1.82406312
# parameter = -1.82420384
# parameter = -1.82434456
# parameter = -1.82448528
# parameter = -1.824626
# parameter = -1.82476672
# parameter = -1.82490744
# parameter = -1.82504816
# parameter = -1.82518888
# parameter = -1.8253296
# parameter = -1.82547032
# parameter = -1.82561104
# parameter = -1.82575176
# parameter = -1.82589248
# parameter = -1.8260332
# parameter = -1.82617392
# parameter = -1.82631464
# parameter = -1.82645536
# parameter = -1.82659608
# parameter = -1.8267368
# parameter = -1.82687752
# parameter = -1.82701824
# parameter = -1.82715896
# parameter = -1.82729968
# parameter = -1.8274404
# parameter = -1.82758112
# parameter = -1.82772184
# parameter = -1.82786256
# parameter = -1.82800328
# parameter = -1.828144
# parameter = -1.82828472
# parameter = -1.82842544
# parameter = -1.82856616
# parameter = -1.82870688
# parameter = -1.8288476
# parameter = -1.82898832
# parameter = -1.82912904
# parameter = -1.82926976
# parameter = -1.82941048
# parameter = -1.8295512
# parameter = -1.82969192
# parameter = -1.82983264
# parameter = -1.82997336
# parameter = -1.83011408
# parameter = -1.8302548
# parameter = -1.83039552
# parameter = -1.83053624
# parameter = -1.83067696
# parameter = -1.83081768
# parameter = -1.8309584
# parameter = -1.83109912
# parameter = -1.83123984
# parameter = -1.83138056
# parameter = -1.83152128
# parameter = -1.831662
# parameter = -1.83180272
# parameter = -1.83194344
# parameter = -1.83208416
# parameter = -1.83222488
# parameter = -1.8323656
# parameter = -1.83250632
# parameter = -1.83264704
# parameter = -1.83278776
# parameter = -1.83292848
# parameter = -1.8330692
# parameter = -1.83320992
# parameter = -1.83335064
# parameter = -1.83349136
# parameter = -1.83363208
# parameter = -1.8337728
# parameter = -1.83391352
# parameter = -1.83405424
# parameter = -1.83419496
# parameter = -1.83433568
# parameter = -1.8344764
# parameter = -1.83461712
# parameter = -1.83475784
# parameter = -1.83489856
# parameter = -1.83503928
# parameter = -1.83518
# parameter = -1.83532072
# parameter = -1.83546144
# parameter = -1.83560216
# parameter = -1.83574288
# parameter = -1.8358836
# parameter = -1.83602432
# parameter = -1.83616504
# parameter = -1.83630576
# parameter = -1.83644648
# parameter = -1.8365872
# parameter = -1.83672792
# parameter = -1.83686864
# parameter = -1.83700936
# parameter = -1.83715008
# parameter = -1.8372908
# parameter = -1.83743152
# parameter = -1.83757224
# parameter = -1.83771296
# parameter = -1.83785368
# parameter = -1.8379944
# parameter = -1.83813512
# parameter = -1.83827584
# parameter = -1.83841656
# parameter = -1.83855728
# parameter = -1.838698
# parameter = -1.83883872
# parameter = -1.83897944
# parameter = -1.83912016
# parameter = -1.83926088
# parameter = -1.8394016
# parameter = -1.83954232
# parameter = -1.83968304
# parameter = -1.83982376
# parameter = -1.83996448
# parameter = -1.8401052
# parameter = -1.84024592
# parameter = -1.84038664
# parameter = -1.84052736
# parameter = -1.84066808
# parameter = -1.8408088
# parameter = -1.84094952
# parameter = -1.84109024
# parameter = -1.84123096
# parameter = -1.84137168
# parameter = -1.8415124
# parameter = -1.84165312
# parameter = -1.84179384
# parameter = -1.84193456
# parameter = -1.84207528
# parameter = -1.842216
# parameter = -1.84235672
# parameter = -1.84249744
# parameter = -1.84263816
# parameter = -1.84277888
# parameter = -1.8429196
# parameter = -1.84306032
# parameter = -1.84320104
# parameter = -1.84334176
# parameter = -1.84348248
# parameter = -1.8436232
# parameter = -1.84376392
# parameter = -1.84390464
# parameter = -1.84404536
# parameter = -1.84418608
# parameter = -1.8443268
# parameter = -1.84446752
# parameter = -1.84460824
# parameter = -1.84474896
# parameter = -1.84488968
# parameter = -1.8450304
# parameter = -1.84517112
# parameter = -1.84531184
# parameter = -1.84545256
# parameter = -1.84559328
# parameter = -1.845734
# parameter = -1.84587472
# parameter = -1.84601544
# parameter = -1.84615616
# parameter = -1.84629688
# parameter = -1.8464376
# parameter = -1.84657832
# parameter = -1.84671904
# parameter = -1.84685976
# parameter = -1.84700048
# parameter = -1.8471412
# parameter = -1.84728192
# parameter = -1.84742264
# parameter = -1.84756336
# parameter = -1.84770408
# parameter = -1.8478448
# parameter = -1.84798552
# parameter = -1.84812624
# parameter = -1.84826696
# parameter = -1.84840768
# parameter = -1.8485484
# parameter = -1.84868912
# parameter = -1.84882984
# parameter = -1.84897056
# parameter = -1.84911128
# parameter = -1.849252
# parameter = -1.84939272
# parameter = -1.84953344
# parameter = -1.84967416
# parameter = -1.84981488
# parameter = -1.8499556
# parameter = -1.85009632
# parameter = -1.85023704
# parameter = -1.85037776
# parameter = -1.85051848
# parameter = -1.8506592
# parameter = -1.85079992
# parameter = -1.85094064
# parameter = -1.85108136
# parameter = -1.85122208
# parameter = -1.8513628
# parameter = -1.85150352
# parameter = -1.85164424
# parameter = -1.85178496
# parameter = -1.85192568
# parameter = -1.8520664
# parameter = -1.85220712
# parameter = -1.85234784
# parameter = -1.85248856
# parameter = -1.85262928
# parameter = -1.85277
# parameter = -1.85291072
# parameter = -1.85305144
# parameter = -1.85319216
# parameter = -1.85333288
# parameter = -1.8534736
# parameter = -1.85361432
# parameter = -1.85375504
# parameter = -1.85389576
# parameter = -1.85403648
# parameter = -1.8541772
# parameter = -1.85431792
# parameter = -1.85445864
# parameter = -1.85459936
# parameter = -1.85474008
# parameter = -1.8548808
# parameter = -1.85502152
# parameter = -1.85516224
# parameter = -1.85530296
# parameter = -1.85544368
# parameter = -1.8555844
# parameter = -1.85572512
# parameter = -1.85586584
# parameter = -1.85600656
# parameter = -1.85614728
# parameter = -1.856288
# parameter = -1.85642872
# parameter = -1.85656944
# parameter = -1.85671016
# parameter = -1.85685088
# parameter = -1.8569916
# parameter = -1.85713232
# parameter = -1.85727304
# parameter = -1.85741376
# parameter = -1.85755448
# parameter = -1.8576952
# parameter = -1.85783592
# parameter = -1.85797664
# parameter = -1.85811736
# parameter = -1.85825808
# parameter = -1.8583988
# parameter = -1.85853952
# parameter = -1.85868024
# parameter = -1.85882096
# parameter = -1.85896168
# parameter = -1.8591024
# parameter = -1.85924312
# parameter = -1.85938384
# parameter = -1.85952456
# parameter = -1.85966528
# parameter = -1.859806
# parameter = -1.85994672
# parameter = -1.86008744
# parameter = -1.86022816
# parameter = -1.86036888
# parameter = -1.8605096
# parameter = -1.86065032
# parameter = -1.86079104
# parameter = -1.86093176
# parameter = -1.86107248
# parameter = -1.8612132
# parameter = -1.86135392
# parameter = -1.86149464
# parameter = -1.86163536
# parameter = -1.86177608
# parameter = -1.8619168
# parameter = -1.86205752
# parameter = -1.86219824
# parameter = -1.86233896
# parameter = -1.86247968
# parameter = -1.8626204
# parameter = -1.86276112
# parameter = -1.86290184
# parameter = -1.86304256
# parameter = -1.86318328
# parameter = -1.863324
# parameter = -1.86346472
# parameter = -1.86360544
# parameter = -1.86374616
# parameter = -1.86388688
# parameter = -1.8640276
# parameter = -1.86416832
# parameter = -1.86430904
# parameter = -1.86444976
# parameter = -1.86459048
# parameter = -1.8647312
# parameter = -1.86487192
# parameter = -1.86501264
# parameter = -1.86515336
# parameter = -1.86529408
# parameter = -1.8654348
# parameter = -1.86557552
# parameter = -1.86571624
# parameter = -1.86585696
# parameter = -1.86599768
# parameter = -1.8661384
# parameter = -1.86627912
# parameter = -1.86641984
# parameter = -1.86656056
# parameter = -1.86670128
# parameter = -1.866842
# parameter = -1.86698272
# parameter = -1.86712344
# parameter = -1.86726416
# parameter = -1.86740488
# parameter = -1.8675456
# parameter = -1.86768632
# parameter = -1.86782704
# parameter = -1.86796776
# parameter = -1.86810848
# parameter = -1.8682492
# parameter = -1.86838992
# parameter = -1.86853064
# parameter = -1.86867136
# parameter = -1.86881208
# parameter = -1.8689528
# parameter = -1.86909352
# parameter = -1.86923424
# parameter = -1.86937496
# parameter = -1.86951568
# parameter = -1.8696564
# parameter = -1.86979712
# parameter = -1.86993784
# parameter = -1.87007856
# parameter = -1.87021928
# parameter = -1.87036

# %%
# Сечение Пуанкаре E = 15
f = Figure(resolution = (1200, 400))
axis = Axis(f[1,1]; xlabel = L"I_0", ylabel = L"x", xlabelsize = 30, ylabelsize = 30,
            xticklabelsize = 25, yticklabelsize = 25, xgridvisible = false, ygridvisible = false)
for (j, p) in enumerate(I0range)
    scatter!(axis, fill(p, length(output[j])), output[j]; color = ("black", 0.5), markersize = 1.5)
end
f

# %%
# Сечение Пуанкаре E = 10
f = Figure(resolution = (1200, 400))
axis = Axis(f[1,1]; xlabel = L"I_0", ylabel = L"x", xlabelsize = 30, ylabelsize = 30,
            xticklabelsize = 25, yticklabelsize = 25, xgridvisible = false, ygridvisible = false)
for (j, p) in enumerate(I0range)
    scatter!(axis, fill(p, length(output[j])), output[j]; color = ("black", 0.5), markersize = 1.5)
end
f

# %%
# Сечение Пуанкаре y = 0.46
f = Figure(resolution = (1200, 400))
axis = Axis(f[1,1]; xlabel = L"I_0", ylabel = L"E", xlabelsize = 30, ylabelsize = 30,
            xticklabelsize = 25, yticklabelsize = 25, xgridvisible = false, ygridvisible = false)
for (j, p) in enumerate(I0range)
    scatter!(axis, fill(p, length(output[j])), output[j]; color = ("black", 0.5), markersize = 1.5)
end
f
