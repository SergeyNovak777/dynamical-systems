# %%
using Pkg
Pkg.activate("C:\\Users\\Alex\\Desktop\\repo\\2612\\0903\\dynamical-systems\\env\\integrate\\")
# Out:
#   Activating project at `C:\Users\Alex\Desktop\repo\2612\0903\dynamical-systems\env\integrate`

# %%
using JLD, CairoMakie

# %%
cd("C:\\Users\\Alex\\Desktop\\repo\\2612\\0903\\dynamical-systems\\Tsodyks Markram\\Levanova\\3 набор параметров\\Сопоставление с матконт")

# %%
Λs= load("LSs_200_200_time_1000.jld")["data"];
u0s = load("u0s_200_200_time_1000.jld")["data"];

# %%
I0range = range( -0.5, -2.0,  length = 200 )
U0range = range( 0.22,  0.55, length = 200 )
# Out:
# 0.22:0.0016582914572864321:0.55

# %%
I0range[134], U0range[19]
# Out:
# (-1.5025125628140703, 0.24984924623115579)

# %%
println(u0s[134, 19, :])
# Out:
# [10.870367054955267, 0.6670395183801261, 0.44434050730193664]

# %%
index = 1
I0st, I0ed = 1, 200
U0st, U0ed = 1, 200
absmax = maximum(abs.(Λs[I0st:I0ed, U0st:U0ed, index]))

mn, mx =  -absmax, absmax

f = Figure()
ax1 = Axis(f[1, 1], xlabel = L"I0",ylabel = L"U0", xlabelsize = 50, ylabelsize = 50,
            xticklabelsize = 35, yticklabelsize = 35,
            xgridvisible  = false, ygridvisible = false)

hm = heatmap!(ax1, I0range[I0st:I0ed], U0range[U0st:U0ed], Λs[I0st:I0ed, U0st:U0ed, index], colormap = :seismic, colorrange = (mn, mx))
Colorbar(f[1, 2], hm)
f
