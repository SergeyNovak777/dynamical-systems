# %%
using JLD, CairoMakie
# Out:
# [ Info: Precompiling JLD [4138dd39-2aa7-5051-a626-17a0bb65d9c8]
# WARNING: could not import HDF5.exists into JLD
# [ Info: Precompiling CairoMakie [13f3f980-e62b-5c42-98c6-ff1f3baf88f0]

# %%
path = "C:\\Users\\HOME\\Downloads"
# Out:
# "C:\\Users\\HOME\\Downloads"

# %%
EEs = load("map_EEs_equal_00.jld")["data"]
LSE = load("spectrum_00.jld")["data"];

# %%
EEs_01 = load("map_EEs_equal_01.jld")["data"]
LSE_01 = load("spectrum_01.jld")["data"];

# %%
k1_k2 = range(-0.5, 0.5, step = 0.01);

# %%
EE_mapcopy = EEs;
EE_mapcopy = [ iszero(x) ? NaN : x for x in EE_mapcopy ]

EE_mapcopy_01 = EEs_01;
EE_mapcopy_01 = [ iszero(x) ? NaN : x for x in EE_mapcopy_01 ];

# %%
f = Figure()

ax1 = Axis(f[1, 1], xlabel = L"k_1",ylabel = L"k_2", xlabelsize = 50, ylabelsize = 50,
            xticklabelsize = 35, yticklabelsize = 35,
            xgridvisible  = false, ygridvisible = false)

hm1 = heatmap!(ax1, k1_k2, k1_k2, LSE_01, colormap = :rainbow1)
save("LSE_k_01_julia.eps", f)
f

# %%
f = Figure()

ax1 = Axis(f[1, 1], xlabel = L"k_1",ylabel = L"k_2", xlabelsize = 50, ylabelsize = 50,
            xticklabelsize = 35, yticklabelsize = 35,
            xgridvisible  = false, ygridvisible = false)

hm1 = heatmap!(ax1, k1_k2, k1_k2, log10.(EE_mapcopy_01), colormap = :jet)
save("EEs_k_01_julia.eps", f)
f
