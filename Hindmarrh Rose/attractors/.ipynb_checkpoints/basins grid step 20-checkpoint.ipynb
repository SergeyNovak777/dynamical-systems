# %%
using DynamicalSystems, CairoMakie,  DifferentialEquations, OrdinaryDiffEq
using StaticArrays

# %%
function sigma(x)
    return @fastmath 1.0 / ( 1.0 + exp( -10.0 * ( x  - ( - 0.25 ) ) ) )
end

function HR(u, p, t)
        
    a, b, c, d, s, xr, r,  I, vs, k1, k2, el_link  = p
    x1, y1, z1, x2, y2, z2 = u
    
    du1 = y1 + b * x1 ^ 2 - a * x1 ^3 - z1 + I - k1 * ( x1 - vs ) * sigma(x2) + el_link * ( x2 - x1 )
    du2 = c - d * x1 ^2 - y1
    du3 = r * ( s * ( x1 - xr ) - z1 )
    
    du4 = y2 + b * x2 ^ 2 - a * x2 ^3 - z2 + I - k2 * ( x2 - vs ) * sigma(x1) + el_link * ( x1 - x2 )
    du5 = c - d * x2 ^2 - y2
    du6 = r * ( s * ( x2 - xr ) - z2 )
    return SVector(du1, du2, du3,
                    du4, du5, du6)
end
# Out:
# HR (generic function with 1 method)

# %%
a = 1.; b = 3.; c = 1.; d = 5.;
xr = -1.6; r = 0.01; s = 5.; I = 4.; xv = 2.;
k1= -0.17; k2 = -0.17;
k = 0.0
condition = SA[-1.5, 0.0, 0.0, -2.5, 0.0, 0.0]
# condition = SA[-0.5, -0.5, -0.5, -0.5, 0-0.5, -0.5]

p = SA[a, b, c, d,
        s, xr, r, I, xv, k1, k2, k]
# Out:
# 12-element SArray{Tuple{12}, Float64, 1, 12} with indices SOneTo(12):
#   1.0
#   3.0
#   1.0
#   5.0
#   5.0
#  -1.6
#   0.01
#   4.0
#   2.0
#  -0.17
#  -0.17
#   0.0

# %%
p = [a, b, c, d, s, xr, r, I, xv, k1, k2, k]
ds_HR = ContinuousDynamicalSystem(HR,  condition, p )
# Out:
# 6-dimensional continuous dynamical system
#  state:       [-1.5, 0.0, 0.0, -2.5, 0.0, 0.0]
#  rule f:      HR
#  in-place?    false
#  jacobian:    ForwardDiff
#  parameters:  [1.0, 3.0, 1.0, 5.0, 5.0, -1.6, …, 4.0, 2.0, -0.17, -0.17, 0.0]

# %%
xg1 = yg1 = zg1 =  xg2 = yg2 = zg2 = range(-5.5, 5.5; length = 10)

mapper = AttractorsViaRecurrences(ds_HR, (xg1, yg1, zg1, xg2, yg2, zg2),
                                    diffeq = (alg = AutoVern9(Rodas5()),
                                                abstol = 1e-11, reltol = 1e-11, dense = false,  maxiters = 10000000))
# Out:
# ┌ Info: Automatic Δt estimation yielded Δt = 0.1962573352913772
# └ @ ChaosTools C:\Users\olenin.s\.julia\packages\ChaosTools\PHPDF\src\basins\attractor_mapping_recurrences.jl:238
# AttractorsViaRecurrences
#  rule f:      HR
#  type:        ODEIntegrator
#  attractors:  Dict{Int16, Dataset{6, Float64}}()
#  grid:        (-5.5:1.2222222222222223:5.5, -5.5:1.2222222222222223:5.5, -5.5:1.2222222222222223:5.5, -5.5:1.2222222222222223:5.5, -5.5:1.2222222222222223:5.5, -5.5:1.2222222222222223:5.5)

# %%
xg1[1], xg1[2], xg1[3], xg1[4]
# Out:
# (-5.5, -4.277777777777778, -3.0555555555555554, -1.8333333333333333)

# %%
basins, attractors = basins_of_attraction(mapper)
attractors
# Out:
# ┌ Info: AttractorsViaRecurrences found new attractor with id: 1
# └ @ ChaosTools C:\Users\olenin.s\.julia\packages\ChaosTools\PHPDF\src\basins\attractor_mapping_recurrences.jl:412
# Basins of attraction: 100%|█████████████████████████████| Time: 0:17:50
# Dict{Int16, Dataset{6, Float64}} with 1 entry:
#   1 => 6-dimensional Dataset{Float64} with 11 points

# %%
COLORS = [
    "#1B1B1B",
    "#6D44D0",
    "#2CB3BF",
    "#DA5210",
    "#03502A",
    "#866373",
    "white",
    "blue",
]
# Out:
# 8-element Vector{String}:
#  "#1B1B1B"
#  "#6D44D0"
#  "#2CB3BF"
#  "#DA5210"
#  "#03502A"
#  "#866373"
#  "white"
#  "blue"

# %%
fig = Figure()
ax = Axis3(fig[1,1])

for i in keys(attractors)
    
    tr = attractors[i]
    color = COLORS[i]
    
    idxs = [1,2,3]
    
    x,y,z = columns(tr)[idxs]
    scatter!(ax, x,y,z; color =color)
    
    tr = trajectory(ds_HR, 5000, tr[1]; Ttr = 1000, diffeq = (alg = AutoVern9(Rodas5()), abstol = 1e-11, reltol = 1e-11,  maxiters = 10000000) )
    
    x,y,z = columns(tr)[idxs]
    
    lines!(ax, x,y,z; linewidth = 1.0, color = color)

end

fig
# Out:
# Figure()

# %%
fig = Figure()
ax = Axis3(fig[1,1])
cmap = cgrad(:dense, 8; categorical = true)

for i in keys(attractors)
    
    tr = attractors[i]
    
    marker = length(attractors[i]) > 10 ? :circle : :rect
    
    idxs = [1,2,3]
    
    x,y,z = columns(tr)[idxs]
    
    scatter!(ax, x,y,z; marker, transparency = true, color = cmap[i])
    
    
    tr = trajectory(ds_HR, 6000, tr[1], Ttr = 1000;
                    diffeq = (alg = AutoVern9(Rodas5()), abstol = 1e-11, reltol = 1e-11,  maxiters = 10000000) )
    
    x,y,z = columns(tr)[idxs]
    
    lines!(ax, x,y,z; linewidth = 1.0, color = cmap[i])

end

fig
# Out:
# Figure()

# %%
fig = Figure()
ax = Axis3(fig[1,1])

for i in keys(attractors)
    
    tr = attractors[i]
    color = COLORS[i]
    
    idxs = [1,2,3]
    
    x,y,z = columns(tr)[idxs]
    scatter!(ax, x,y,z; color =color)
    
    tr = trajectory(ds_HR, 5000, tr[1]; Ttr = 1000, diffeq = (alg = AutoVern9(Rodas5()), abstol = 1e-11, reltol = 1e-11,  maxiters = 10000000) )
    
    x,y,z = columns(tr)[idxs]
    
    lines!(ax, x,y,z; linewidth = 1.0, color = color)

end

fig
# Out:
# Figure()

# %%
fig = Figure()
ax = Axis3(fig[1,1])
cmap = cgrad(:dense, 8; categorical = true)

for i in keys(attractors)
    
    tr = attractors[i]
    
    marker = length(attractors[i]) > 10 ? :circle : :rect
    
    idxs = [1,2,3]
    
    x,y,z = columns(tr)[idxs]
    
    scatter!(ax, x,y,z; marker, transparency = true, color = cmap[i])
    
    
    tr = trajectory(ds_HR, 6000, tr[1], Ttr = 1000;
                    diffeq = (alg = AutoVern9(Rodas5()), abstol = 1e-11, reltol = 1e-11,  maxiters = 10000000) )
    
    x,y,z = columns(tr)[idxs]
    
    lines!(ax, x,y,z; linewidth = 1.0, color = cmap[i])

end

fig
# Out:
# Figure()

# %%
fig = Figure()
ax = Axis3(fig[1,1])
cmap = cgrad(:dense, 8; categorical = true)

for i in keys(attractors)
    
    tr = attractors[i]
    
    marker = length(attractors[i]) > 10 ? :circle : :rect
    
    idxs = [1,2,3]
    
    x,y,z = columns(tr)[idxs]
    
    scatter!(ax, x,y,z; marker, transparency = true, color = cmap[i])
    

end

fig
# Out:
# Figure()

# %%
fig = Figure()
ax = Axis3(fig[1,1])

for i in keys(attractors)
    
    tr = attractors[i]
    color = COLORS[i]
    
    idxs = [1,2,3]
    
    x,y,z = columns(tr)[idxs]
    scatter!(ax, x,y,z; color =color)
    


end

fig
# Out:
# Figure()

# %%
fig = Figure(resolution  = (1200, 1200))
ax = Axis3(fig[1,1])

for i in keys(attractors)
    
    tr = attractors[i]
    color = COLORS[i]
    
    idxs = [1,2,3]
    
    x,y,z = columns(tr)[idxs]
    scatter!(ax, x,y,z; color =color)
    
    tr = trajectory(ds_HR, 5000, tr[1]; Ttr = 1000, diffeq = (alg = AutoVern9(Rodas5()), abstol = 1e-11, reltol = 1e-11,  maxiters = 10000000) )
    
    x,y,z = columns(tr)[idxs]
    
    lines!(ax, x,y,z; linewidth = 1.0, color = color)

end

fig
# Out:
# Figure()
