# %%
using DelimitedFiles
using CairoMakie

# %%
function parabola(x)
    a = 0.13625841750841752
    b = 0.189709595959596
    c = 0.22
    return  a * (x.^2) + b * x .+ c 
end

# %%
pwd()
# Out:
# "C:\\Users\\Alex\\Desktop\\dynamical-systems\\Tsodyks&Markram"

# %%
cd("C:\\Users\\Alex\\Desktop\\repo\\2612\\dynamical-systems\\Tsodyks&Markram\\")

# %%
startI = -1.8
endI = -1.32
lengthI = 200

rangeI = range( startI, endI, length = lengthI )
# Out:
# -1.8:0.002412060301507538:-1.32

# %%
test = readdlm("2d_map_parabola_zoom.txt")
# Out:
# 2686×3 Matrix{Float64}:
#  -1.75     0.3053    -0.000804791
#  -1.74977  0.305235  -0.00302105
#  -1.75     0.305235  -0.00200957
#  -1.74955  0.30517    0.0037958
#  -1.74977  0.30517    0.00450681
#  -1.75     0.30517   -0.00518423
#  -1.74932  0.305105  -0.00861621
#  -1.74955  0.305105  -0.00179246
#  -1.74977  0.305105  -0.00814398
#  -1.75     0.305105  -0.00260277
#  -1.7491   0.30504   -0.00382989
#  -1.74932  0.30504   -0.00716097
#  -1.74955  0.30504    0.00996333
#   ⋮
#  -1.74412  0.30066   -0.316675
#  -1.74435  0.30066   -0.316252
#  -1.74457  0.30066   -0.316292
#  -1.7448   0.30066   -0.315968
#  -1.74503  0.30066   -0.3166
#  -1.74525  0.30066   -0.31616
#  -1.74548  0.30066   -0.316824
#  -1.7457   0.30066   -0.316708
#  -1.74593  0.30066   -0.317274
#  -1.74616  0.30066   -0.317629
#  -1.74638  0.30066   -0.318351
#  -1.74661  0.30066   -0.317698

# %%
f = Figure()
ax = Axis(f[1, 1], xlabel = L"I0", ylabel = "U0", xlabelsize = 25, ylabelsize = 25,
            xticklabelsize = 18, yticklabelsize = 18)

xlims!(-1.75, -1.706)
ylims!(0.29, 0.305)

h = scatter!(test[:, 1], test[:, 2], markersize = 4, color = test[:, 3], colormap = :thermal)
lines!(rangeI, parabola(rangeI), color = "black", linestyle = :dash, linewidth = 2.0)

Colorbar(f[1, 2], h)
f
# Out:
# Figure()
