# %%
using DynamicalSystems, DifferentialEquations, OrdinaryDiffEq, StaticArrays, CairoMakie

# %% [markdown]
# ### Green space
#
# U0 = 0.23
#
# I0 = -1.45
#
# u0 = SA[1.46577,  0.7359,    0.65397,   0.053783];

# %% [markdown]
# ### Red space
#
# U0 = 0.25
#
# I0 = -1.45
#
# u0 = SA[1.46577,  0.7359,    0.65397,   0.053783];

# %%
τ = 0.013
α = 1.5
J = 3.07
τ_D = 0.15
U0 = 0.25
τ_F = 1
ΔU0 = 0.305
τ_y = 1.8
β = 0.4375
xthr = 0.9
ythr = 0.5
I0 = -1.45 # -1.45
# Out:
# -1.45

# %%
U(y) = U0 + ΔU0 / ( 1 + exp( -50 * ( y - ythr ) ) )
σ(x)= 1 / (1 + exp(-20 * (x - xthr)))
# Out:
# σ (generic function with 1 method)

# %%
function model(u, p ,t)
    
    E, x, u_, y = u
    τ, α, τ_D, J, U0, ΔU0, τ_y, β, xthr, ythr, I0 = p
    
    du1 = (-E + α * log( 1 + exp( ( J * u_ * x * E + I0 ) / α ) )) / τ
    du2 = ( 1 - x ) / τ_D - u_ * x * E
    du3 = (U(y) - u_) / τ_F + U(y) * ( 1 - u_ ) * E
    du4 = -y /  τ_y + β * σ(x)
    
    return SVector(du1, du2, du3, du4)
    
end
# Out:
# model (generic function with 1 method)

# %%
p = SA[τ, α, τ_D, J, U0, ΔU0, τ_y, β, xthr, ythr, I0]
u0 = SA[1.46577,  0.7359,    0.65397,   0.053783];
tspan = (0.0, 1500.0)
# Out:
# (0.0, 1500.0)

# %%
ds = ContinuousDynamicalSystem(model, u0, p)
# Out:
# 4-dimensional continuous dynamical system
#  state:       [1.46577, 0.7359, 0.65397, 0.053783]
#  rule f:      model
#  in-place?    false
#  jacobian:    ForwardDiff
#  parameters:  [0.013, 1.5, 0.15, 3.07, 0.25, …, 1.8, 0.4375, 0.9, 0.5, -1.45]

# %%
ds.p
# Out:
# 11-element SVector{11, Float64} with indices SOneTo(11):
#   0.013
#   1.5
#   0.15
#   3.07
#   0.25
#   0.305
#   1.8
#   0.4375
#   0.9
#   0.5
#  -1.45

# %%
tr = trajectory(ds, tspan[2], Ttr = tspan[2]/2; Δt = 0.001, diffeq = (alg = RK4(),  adaptive = false, dt = 0.01))
# Out:
# 4-dimensional Dataset{Float64} with 1500001 points
#   3.12197  0.545633  0.751879  0.0063118
#   3.09321  0.54738   0.75157   0.00630867
#   3.06503  0.549123  0.75126   0.00630555
#   3.03741  0.550863  0.750949  0.00630245
#   3.01035  0.552599  0.750637  0.00629936
#   2.98384  0.554331  0.750323  0.00629629
#   2.95786  0.556059  0.750008  0.00629323
#   2.93242  0.557783  0.749693  0.00629019
#   2.90751  0.559502  0.749376  0.00628717
#   2.88311  0.561218  0.749058  0.00628417
#   2.85922  0.562929  0.74874   0.00628119
#   2.83583  0.564635  0.74842   0.00627823
#   2.81293  0.566337  0.7481    0.00627528
#   ⋮
#  13.7138   0.39164   0.764566  0.00670594
#  13.5179   0.391618  0.764852  0.00670223
#  13.3236   0.391653  0.765125  0.00669853
#  13.131    0.391744  0.765386  0.00669482
#  12.9402   0.391888  0.765635  0.00669112
#  12.7513   0.392086  0.765872  0.00668742
#  12.5642   0.392335  0.766096  0.00668372
#  12.3792   0.392634  0.766309  0.00668003
#  12.1961   0.392983  0.76651   0.00667634
#  12.0152   0.39338   0.7667    0.00667264
#  11.8364   0.393823  0.766878  0.00666896
#  11.6599   0.394312  0.767046  0.00666527

# %%
f = Figure(resolution = (1600, 700))

ax1 = Axis(f[1, 1], xlabel = "t", ylabel = "E", xlabelsize = 22, ylabelsize = 22,xticklabelsize = 17, yticklabelsize = 17)
ax2 = Axis(f[2, 1], xlabel = "t", ylabel = "X, u, Y", xlabelsize = 22, ylabelsize = 22,xticklabelsize = 17, yticklabelsize = 17)

ts, tf = 1, 30000

lines!(ax1, tr[ts:tf, 1], color = "blue", label = "E")

lines!(ax2, tr[ts:tf, 2], color = "red", label = "X")
lines!(ax2, tr[ts:tf, 3], color = "green", label = "u")
lines!(ax2, tr[ts:tf, 4], color = "orange", label = "Y")

axislegend(ax2, labelsize=15)
f
# Out:
# Figure()

# %%
f = Figure(resolution = (1600, 1600))
ts, tf = 1, 20000
ax = Axis3(f[1, 1])
lines!(tr[ts:tf, 2], tr[ts:tf, 3], tr[ts:tf, 1], linewidth = 1)
f
# Out:
# Figure()

# %% [markdown]
# ### dt = 0.001

# %%
tspan = (0.0, 1000.0)
λ = lyapunov(ds, tspan[2], Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.001))
# Out:
# 0.0015202679274040065

# %%
# 1000
tspan = (0.0, 1000.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.001) )
# Out:
# 4-element Vector{Float64}:
#   0.0015492227112568694
#  -0.3319383987122578
#  -0.5561209955143407
#  -2.2886265206595273

# %%
# time 1500
tspan = (0.0, 1500.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.001) )
# Out:
# 4-element Vector{Float64}:
#  -0.00033722582468929404
#  -0.33070540017642513
#  -0.5552435239669026
#  -2.2892224837128583

# %%
# time 2000
tspan = (0.0, 2000.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.001) )
# Out:
# 4-element Vector{Float64}:
#   0.0002712776935874419
#  -0.3318901196275303
#  -0.5558845162598454
#  -2.288606647029349

# %%
# time 2500
tspan = (0.0, 2500.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.001) )
# Out:
# 4-element Vector{Float64}:
#  -0.000101809879923816
#  -0.33134212908565636
#  -0.5555535941065899
#  -2.2888465184845788

# %% [markdown]
# ### dt = 0.01

# %%
tspan = (0.0, 1000.0)
λ = lyapunov(ds, tspan[2], Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.01))
# Out:
# -0.0004152837794537852

# %%
# 1000
tspan = (0.0, 1000.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.01) )
# Out:
# 4-element Vector{Float64}:
#   0.0023852947621601332
#  -0.33645232693902366
#  -0.5555879831432127
#  -2.288663723475082

# %%
# time 1500
tspan = (0.0, 1500.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.01) )
# Out:
# 4-element Vector{Float64}:
#  -0.00263797117872636
#  -0.3346121999643708
#  -0.5555239914625112
#  -2.2887464997324387

# %%
# time 2000
tspan = (0.0, 2000.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.01) )
# Out:
# 4-element Vector{Float64}:
#   0.000653557621956166
#  -0.3367479025904973
#  -0.5555872165654338
#  -2.2887286873363624

# %%
# time 2500
tspan = (0.0, 2500.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.01) )
# Out:
# 4-element Vector{Float64}:
#   0.0002757114908662142
#  -0.3363232922265501
#  -0.5555581447514157
#  -2.2887892946798667
