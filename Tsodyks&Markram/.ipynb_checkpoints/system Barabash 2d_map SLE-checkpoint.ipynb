# %%
using DynamicalSystems, DifferentialEquations, OrdinaryDiffEq, StaticArrays, CairoMakie

# %% [markdown]
# ### Green space
#
# U0 = 0.23
#
# I0 = -1.45
#
# u0 = SA[1.46577,  0.7359,    0.65397,   0.053783];

# %% [markdown]
# ### Red space
#
# U0 = 0.25
#
# I0 = -1.45
#
# u0 = SA[1.46577,  0.7359,    0.65397,   0.053783];

# %% [markdown]
# ### Пачки из трёх спайков
#
# U0 = 0.25
#
# I0 = -1.573
# u0 = 1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071

# %% [markdown]
# ### Пачки из четырех спайков
#
# I0 = -1.5682

# %% [markdown]
# ### измёнен аттрактор
#
# I0 = -1.54980

# %% [markdown]
# ### слишком большая пачка
#
# I0 = -1.54500

# %% [markdown]
# ### бифуркация?
#
# I0 = -1.54490

# %% [markdown]
# I0 = -1.54488275
#
# I0 = -1.54488271
#
# u0 = SA[1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]

# %%
τ = 0.013
α = 1.5
J = 3.07
τ_D = 0.15
U0 = 0.25
τ_F = 1
ΔU0 = 0.305
τ_y = 1.8
β = 0.4375
xthr = 0.9
ythr = 0.5
# Out:
# 0.5

# %%
U(y) = U0 + ΔU0 / ( 1 + exp( -50 * ( y - ythr ) ) )
σ(x)= 1 / (1 + exp(-20 * (x - xthr)))
# Out:
# σ (generic function with 1 method)

# %%
function model(u, p ,t)
    
    E, x, u_, y = u
    τ, α, τ_D, J, U0, ΔU0, τ_y, β, xthr, ythr, I0 = p
    
    du1 = (-E + α * log( 1 + exp( ( J * u_ * x * E + I0 ) / α ) )) / τ
    du2 = ( 1 - x ) / τ_D - u_ * x * E
    du3 = (U(y) - u_) / τ_F + U(y) * ( 1 - u_ ) * E
    du4 = -y /  τ_y + β * σ(x)
    
    return SVector(du1, du2, du3, du4)
    
end
# Out:
# model (generic function with 1 method)

# %%
I0 = -1.54980

p = SA[τ, α, τ_D, J, U0, ΔU0, τ_y, β, xthr, ythr, I0]
u0 = SA[1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
tspan = (0.0, 2000.0)

ds = ContinuousDynamicalSystem(model, u0, p)

println(ds.p)
tr = trajectory(ds, tspan[2], Ttr = tspan[2]/2; Δt = 0.001, diffeq = (alg = RK4(),  adaptive = false, dt = 0.01))
# Out:
# [0.013, 1.5, 0.15, 3.07, 0.25, 0.305, 1.8, 0.4375, 0.9, 0.5, -1.5498]
# 4-dimensional Dataset{Float64} with 2000001 points
#  2.84275  0.827825  0.625391  0.166797
#  2.86764  0.827497  0.625283  0.166788
#  2.89313  0.827158  0.625177  0.166778
#  2.91923  0.826809  0.625075  0.166768
#  2.94598  0.82645   0.624975  0.166757
#  2.97339  0.82608   0.624877  0.166746
#  3.00149  0.825699  0.624782  0.166734
#  3.0303   0.825307  0.624691  0.166722
#  3.05985  0.824903  0.624602  0.166709
#  3.09017  0.824488  0.624516  0.166696
#  3.12126  0.824061  0.624433  0.166682
#  3.15316  0.823622  0.624353  0.166668
#  3.18591  0.82317   0.624276  0.166653
#  ⋮
#  1.2418   0.73031   0.675291  0.0753487
#  1.23972  0.731492  0.674966  0.0753213
#  1.23775  0.732666  0.674642  0.0752941
#  1.2359   0.733833  0.674319  0.0752674
#  1.23415  0.734992  0.673995  0.0752409
#  1.23251  0.736144  0.673672  0.0752149
#  1.23098  0.737288  0.673349  0.0751892
#  1.22955  0.738424  0.673026  0.0751639
#  1.22823  0.739553  0.672704  0.0751389
#  1.227    0.740675  0.672382  0.0751144
#  1.22587  0.741789  0.67206   0.0750902
#  1.22483  0.742895  0.671739  0.0750664

# %%
f = Figure(resolution = (1600, 400))

ax1 = Axis(f[1, 1], xlabel = "t", ylabel = "E", xlabelsize = 22, ylabelsize = 22,xticklabelsize = 17, yticklabelsize = 17)
ax2 = Axis(f[2, 1], xlabel = "t", ylabel = "X, u, Y", xlabelsize = 22, ylabelsize = 22,xticklabelsize = 17, yticklabelsize = 17)

ts, tf = 1, 20000

lines!(ax1, tr[ts:tf, 1], color = "blue", label = "E")

lines!(ax2, tr[ts:tf, 2], color = "red", label = "X")
lines!(ax2, tr[ts:tf, 3], color = "green", label = "u")
lines!(ax2, tr[ts:tf, 4], color = "orange", label = "Y")

axislegend(ax2, labelsize=20)
f
# Out:
# Figure()

# %%
f = Figure(resolution = (1000, 1000))
ts, tf = 1, 200000
ax = Axis3(f[1, 1])
lines!(tr[ts:tf, 2], tr[ts:tf, 3], tr[ts:tf, 1], linewidth = 1)
f
# Out:
# Figure()

# %%
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.01) )
# Out:
# 4-element Vector{Float64}:
#    0.04892225622569782
#    0.00027145620881887874
#   -2.7350327736050324
#  -13.733457207939693

# %%
u0 = SA[1.46577,  0.7359,    0.65397,   0.053783];
tspan = (0.0, 2500.0)
# Out:
# (0.0, 2500.0)

# %%
p_start =  -1.7418
p_finish = -1.738
p_step = 0.00005
range_p = range(p_start, p_finish, step = p_step)
# Out:
# -1.7418:5.0e-5:-1.738

# %%
length(range_p)
# Out:
# 77

# %%
array_initial_condition = zeros(length(range_p), 4 )
array_SLE = zeros(length(range_p), 4 );

# %%
for (index, p_lc) in enumerate(range_p)
    
   

    u0_lc = SA[1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]

    
    println("index: $index; I0: $p_lc");flush(stdout)
    println(" u0: $u0_lc ");flush(stdout)
    
    array_initial_condition[index, :] = u0_lc
    
    p_lc = SA[τ, α, τ_D, J, U0, ΔU0, τ_y, β, xthr, ythr, p_lc]
    ds_lc = ContinuousDynamicalSystem(model, u0_lc, p_lc)
    
    tr = trajectory(ds_lc, tspan[2], Ttr = tspan[2]/2; Δt = 0.001, diffeq = (alg = RK4(),  adaptive = false, dt = 0.01))
    
    λλ = lyapunovspectrum(ds_lc, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.01) )
    println("LSE: $λλ");flush(stdout)
    array_SLE[index, :] = λλ
    println("  ");flush(stdout)
    
    
end
# Out:
# index: 1; I0: -1.7418
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.3153156316189684, -0.31610582088350403, -11.561034075095497, -15.187392413098308]
#
# index: 2; I0: -1.74175
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.0005822166187038995, -0.1553013567203281, -0.5555286161161163, -7.8803737784440155]
#
# index: 57; I0: -1.739
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.0008974822671624454, -0.17303835300165768, -0.5555506193529656, -7.891361930230033]
#
# index: 58; I0: -1.73895
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [0.0017735424273187573, -0.18876915247819492, -0.5553836828044724, -7.902450517660444]
#
# index: 59; I0: -1.7389
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [0.0015265933937367887, -0.203307811294636, -0.5555643594347843, -7.910857212061204]
#
# index: 60; I0: -1.73885
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.0006663668867096178, -0.21675619111637118, -0.555780742481035, -7.918388045972803]
#
# index: 61; I0: -1.7388
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [0.0020988180082621034, -0.22905773131244173, -0.5554565191336568, -7.926769438186836]
#
# index: 62; I0: -1.73875
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [0.00041713135750174766, -0.24082807812496654, -0.5555520009505687, -7.933999927227107]
#
# index: 63; I0: -1.7387
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [0.0008230654917075708, -0.25180031695314486, -0.555325720639527, -7.940676459365683]
#
# index: 64; I0: -1.73865
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.00035062344625414095, -0.2624401747144569, -0.5556560179207214, -7.947036863311794]
#
# index: 65; I0: -1.7386
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.00012803905237586554, -0.2724598063661756, -0.5555943422925499, -7.952398081866597]
#
# index: 66; I0: -1.73855
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.0021690031425758436, -0.2821108461170381, -0.5557996964237227, -7.957304177784901]
#
# index: 67; I0: -1.7385
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [0.00014502376224573998, -0.29125440848008943, -0.5556068820913816, -7.962682896164263]
#
# index: 68; I0: -1.73845
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.0015934980222120072, -0.30013401203815365, -0.5555714881687986, -7.967513863883795]
#
# index: 69; I0: -1.7384
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.001515692187404831, -0.3087049572535624, -0.5556531059029568, -7.973019711994797]
#
# index: 70; I0: -1.73835
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.0017889051621320597, -0.3169775482999315, -0.5556829579986294, -7.977246313291018]
#
# index: 71; I0: -1.7383
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.0010298962052491625, -0.3249767661478555, -0.5556214344825186, -7.981467228415858]
#
# index: 72; I0: -1.73825
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.000769336078216838, -0.3327052336974566, -0.5555065294866535, -7.986325725665984]
#
# index: 73; I0: -1.7382
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.0008993848960245776, -0.3403182913133416, -0.5559776142309556, -7.988866696201604]
#
# index: 74; I0: -1.73815
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [0.00038924722815253084, -0.34756294478653116, -0.555460342042885, -7.994163393721801]
#
# index: 75; I0: -1.7381
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [0.0013999252354118666, -0.35472486989410007, -0.5555601410422228, -7.997864647420833]
#
# index: 76; I0: -1.73805
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [-0.00011635428691209166, -0.36170704751896116, -0.5554307083749646, -8.002023176984384]
#
# index: 77; I0: -1.738
#  u0: [1.3403239669724387, 0.7788950798545725, 0.6941625778210773, 0.03677942307955071]
# LSE: [0.002068686790138063, -0.3684811133000334, -0.5554755303120397, -8.004992458895979]

# %%
f = Figure(resolution = (1200, 400))
ax = Axis(f[1, 1], xlabel = "U0", ylabel = L"λ_1")

lines!(ax, range_p, array_SLE[:, 1], color = "red")
lines!(ax, range_p, array_SLE[:, 2], color = "blue")

hlines!(ax, 0, range_p, linewidth = 1.5, color = "black", linestyle = :dash)
ylims!(-0.4, 0.1)
f
# Out:
# Figure()

# %%
tspan = (0.0, 1000.0)
λ = lyapunov(ds, tspan[2], Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.001))
# Out:
# 0.00016926510439465052

# %%
# 1000
tspan = (0.0, 1000.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.001) )
# Out:
# 4-element Vector{Float64}:
#   0.0015492227112568694
#  -0.3319383987122578
#  -0.5561209955143407
#  -2.2886265206595273

# %%
# time 1500
tspan = (0.0, 1500.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.001) )
# Out:
# 4-element Vector{Float64}:
#  -0.00033722582468929404
#  -0.33070540017642513
#  -0.5552435239669026
#  -2.2892224837128583

# %%
# time 2000
tspan = (0.0, 2000.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.001) )
# Out:
# 4-element Vector{Float64}:
#   0.0002712776935874419
#  -0.3318901196275303
#  -0.5558845162598454
#  -2.288606647029349

# %%
# time 2500
tspan = (0.0, 2500.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.001) )
# Out:
# 4-element Vector{Float64}:
#  -0.000101809879923816
#  -0.33134212908565636
#  -0.5555535941065899
#  -2.2888465184845788

# %%
tspan = (0.0, 1000.0)
λ = lyapunov(ds, tspan[2], Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.01))
# Out:
# -0.0004152837794537852

# %%
# 1000
tspan = (0.0, 1000.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.01) )
# Out:
# 4-element Vector{Float64}:
#   0.0023852947621601332
#  -0.33645232693902366
#  -0.5555879831432127
#  -2.288663723475082

# %%
# time 1500
tspan = (0.0, 1500.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.01) )
# Out:
# 4-element Vector{Float64}:
#  -0.00263797117872636
#  -0.3346121999643708
#  -0.5555239914625112
#  -2.2887464997324387

# %%
# time 2000
tspan = (0.0, 2000.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.01) )
# Out:
# 4-element Vector{Float64}:
#   0.000653557621956166
#  -0.3367479025904973
#  -0.5555872165654338
#  -2.2887286873363624

# %%
# time 2500
tspan = (0.0, 2500.0)
λλ = lyapunovspectrum(ds, tspan[2], Δt = 1, Ttr = tspan[2]/2; diffeq = (alg = RK4(),  adaptive = false, dt = 0.01) )
# Out:
# 4-element Vector{Float64}:
#   0.0002757114908662142
#  -0.3363232922265501
#  -0.5555581447514157
#  -2.2887892946798667
