# %%
username = "Alex"
env = "integrate"
pathtorepo = "C:\\Users\\" *username *  "\\Desktop\\"
using Pkg
Pkg.activate(pathtorepo * "dynamical-systems\\env\\" * env * "\\")
include(pathtorepo * "dynamical-systems\\system.jl")
# Out:
#   Activating project at `C:\Users\Alex\Desktop\dynamical-systems\env\integrate`
# rate_jac (generic function with 1 method)

# %%
using JLD2, CairoMakie, GLMakie

# %%
cd("C:\\Users\\Alex\\Desktop\\dynamical-systems\\")
len = 100
map_dim = " $(len)x$(len) "
name = " γY s0E rate_model params from article RK4"
format = ".jld2"
namefile_LSE = "LSE" * map_dim * name * format
namefile_u0s = "u0s" * map_dim * name * format

Λs = load(namefile_LSE)
Λs = Λs["Λs"]
u0s = load(namefile_u0s)
u0s = u0s["u0s"]

γYrange = range( 0.0, 10.0, length = len );
IErange = range(0.0, 0.5, length = len);

# %%
index = 1
absmax = maximum(abs.(Λs[:, :, index]))

mn, mx =  -absmax, absmax

CairoMakie.activate!()
f = Figure()
ticksize = 25
tickpad = 10.0
textsize = 25

ax = Axis(f[1, 1], xlabel = L"γY",ylabel = L"s_{0}^{E}", xlabelsize = 50, ylabelsize = 50,
            xticklabelsize = ticksize, yticklabelsize = ticksize,
            xgridvisible  = false, ygridvisible = false,
            xticklabelpad = tickpad, yticklabelpad = tickpad)

hm = heatmap!(ax, γYrange, IErange, Λs[:, :, index],
colormap = :seismic, colorrange = (mn, mx))

display(f);

# %%
GLMakie.activate!()
display(GLMakie.Screen(), f);

# %%
pathtosave = "C:\\Users\\Alex\\Desktop\\rate model\\"
filename = "\\gammaY_s0E_params_from_article_RK4.eps"
fullpath = pathtosave * filename 
save(fullpath, f)
# Out:
# CairoMakie.Screen{EPS}
