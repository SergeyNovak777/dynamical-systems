# %%
user = "Alex"
pathtorepo = "C:\\Users\\" * user * "\\Desktop\\"

using Pkg
Pkg.activate(pathtorepo * "dynamical-systems\\env\\integrate\\")

using JLD, CairoMakie
# Out:
#   Activating project at `C:\Users\Alex\Desktop\dynamical-systems\env\integrate`

# %%
pathtofiles = "C:\\Users\\Alex\\Desktop\\dynamical-systems\\brain rhythms\\research_activity"
cd(pathtofiles)

# %%
Λs = load("LSs 500 change γY.jld")["data"]
Λs_1000 = load("LSs 1000 change γY to 50.0.jld")["data"]
Λs_2000 = load("LSs 2000 change γY to 100.0.jld")["data"]

num_spikes = load("num_spieks 500 change γY.jld")["data"]
num_spikes_1000 = load("num_spieks 1000 change γY.jld")["data"]
num_spikes_2000 = load("num_spieks 2000 change γY to 100.0.jld")["data"]

name_control_param = L"γY"
# Out:
# L"$γY$"

# %%
lb_size = 40; tck_size = 35
widthline = 1.5
# Out:
# 1.5

# %%
start_param = 0.0
end_param = 1.0
length_range = 501
param_range = range(start_param, end_param, length = length_range)

st, ed = 1, 501
f = Figure(resolution = (2000, 350))
axis1 = Axis(f[1, 1], xlabel = name_control_param, ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = "LSE γY to 1.0", titlesize = 35)

lines!(axis1, param_range[st:ed], Λs[st:ed, 1], linewidth = widthline, color = :red)
lines!(axis1, param_range[st:ed], Λs[st:ed, 2], linewidth = widthline, color = :green)
lines!(axis1, param_range[st:ed], Λs[st:ed, 3], linewidth = widthline, color = :blue)
hlines!(axis1, 0.0, linestyle = :dash, color = :black, linewidth = 0.5)

display(f)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
start_param = 0.0
end_param = 1.0
length_range = 501
param_range = range(start_param, end_param, length = length_range)

st, ed = 1, 501
f = Figure(resolution = (2000, 350))
axis = Axis(f[1, 1], xlabel = name_control_param, ylabel = L"count",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = "Number of spikes  γY to 1.0", titlesize = 35
            )

lines!(axis, param_range[st:ed], num_spikes[st:ed, 1], linewidth = widthline, color = :blue, label = "rE")
lines!(axis, param_range[st:ed], num_spikes[st:ed, 2], linewidth = widthline, color = :red, label = "rI")
axislegend(axis)
display(f)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
start_param = 0.0
end_param = 50.0
length_range = 1001
param_range = range(start_param, end_param, length = length_range)

st, ed = 1, 1001
f = Figure(resolution = (2000, 350))
axis1 = Axis(f[1, 1], xlabel = name_control_param, ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = "LSE γY to 50", titlesize = 35)

lines!(axis1, param_range[st:ed], Λs_1000[st:ed, 1], linewidth = widthline, color = :red)
lines!(axis1, param_range[st:ed], Λs_1000[st:ed, 2], linewidth = widthline, color = :green)
lines!(axis1, param_range[st:ed], Λs_1000[st:ed, 3], linewidth = widthline, color = :blue)
hlines!(axis1, 0.0, linestyle = :dash, color = :black, linewidth = 0.5)

display(f)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
start_param = 0.0
end_param = 50.0
length_range = 1001
param_range = range(start_param, end_param, length = length_range)

st, ed = 1, 1001
f = Figure(resolution = (2000, 350))
axis = Axis(f[1, 1], xlabel = name_control_param, ylabel = L"count ",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = "Number of spikes γY to 50", titlesize = 35
            )

lines!(axis, param_range[st:ed], num_spikes_1000[st:ed, 1], linewidth = widthline, color = :blue, label = "rE")
lines!(axis, param_range[st:ed], num_spikes_1000[st:ed, 2], linewidth = widthline, color = :red, label = "rI")
axislegend(axis)

display(f)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
start_param = 0.0
end_param = 100.0
length_range = 2001
param_range = range(start_param, end_param, length = length_range)

st, ed = 1, 2001
f = Figure(resolution = (2000, 350))
axis1 = Axis(f[1, 1], xlabel = name_control_param, ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = "LSE γY to 100", titlesize = 35)

lines!(axis1, param_range[st:ed], Λs_2000[st:ed, 1], linewidth = widthline, color = :red)
lines!(axis1, param_range[st:ed], Λs_2000[st:ed, 2], linewidth = widthline, color = :green)
lines!(axis1, param_range[st:ed], Λs_2000[st:ed, 3], linewidth = widthline, color = :blue)
hlines!(axis1, 0.0, linestyle = :dash, color = :black, linewidth = 0.5)

display(f)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
start_param = 0.0
end_param = 100.0
length_range = 2001
param_range = range(start_param, end_param, length = length_range)

st, ed = 1, 2001
f = Figure(resolution = (2000, 350))
axis = Axis(f[1, 1], xlabel = name_control_param, ylabel = L"count ",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = "Number of spikes γY to 100", titlesize = 35
            )

lines!(axis, param_range[st:ed], num_spikes_2000[st:ed, 1], linewidth = widthline, color = :blue, label = "rE")
lines!(axis, param_range[st:ed], num_spikes_2000[st:ed, 2], linewidth = widthline, color = :red, label = "rI")
axislegend(axis)

display(f)
# Out:
# CairoMakie.Screen{IMAGE}
