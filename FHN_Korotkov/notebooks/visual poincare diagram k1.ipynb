# %%
if Sys.iswindows()
    username = "Alex"
    pathtorepo = "C:\\Users\\" *username *  "\\Desktop\\"
    using Pkg
    Pkg.activate(pathtorepo * "dynamical-systems\\env\\integrate\\")
else
    username = "sergey"
    pathtorepo = "/home/" *username *"/work/repo/dynamical-systems"
    using Pkg
    Pkg.activate(pathtorepo * "/env/integrate/")
end

using JLD2, CairoMakie
# Out:
#   Activating project at `~/work/repo/dynamical-systems/env/integrate`

# %%
k1_start = 0.0
k1_end = 0.094
len = 1000
rangek1 = range(k1_start, k1_end, length = len)
# Out:
# 0.0:9.40940940940941e-5:0.094

# %%
output = (load("/home/sergey/work/repo/dynamical-systems/bif_dia_k1_length_1000_z_zero.jld2"))["output"]
# Out:
# 1000-element Vector{Vector{Float64}}:
#  [-1.0919177589463818, -1.0919177679325853, -1.091917765582382, -1.0919177652785002, -1.0919177609983028, -1.0919177646868428, -1.0919177585696975, -1.0919177660046904, -1.0919177638440312, -1.091917769387104  …  -1.0919177558718194, -1.0919177773903734, -1.0919177640391236, -1.0919177775651128, -1.0919177548333436, -1.091917779753065, -1.0919177476360715, -1.0919177839542034, -1.0919177817322196, -1.091917750858655]
#  [-1.0911131816037019, -1.0911132299240172, -1.09111318202511, -1.0911131950047468, -1.0911131940592154, -1.0911131815446697, -1.0911132300567836, -1.0911131820877054, -1.0911131951281607, -1.0911131939393461  …  -1.0911131783630128, -1.0911131863336447, -1.0911132028104245, -1.0911131878795763, -1.0911131788730533, -1.091113178389793, -1.0911131864204535, -1.0911132029580355, -1.0911131877854552, -1.091113178839725]
# ...

# %%
CairoMakie.activate!()
markersize = 1.5;
lbsize = 30;
ticksize = 30;
fig = Figure(size = (1200, 350))
axis = Axis(fig[1,1],
xlabel = L"k_1",  ylabel = L"x_1",
xlabelsize = lbsize, ylabelsize = lbsize,
xticklabelsize = ticksize,yticklabelsize = ticksize, xgridvisible = false, ygridvisible = false)

for (j, p) in enumerate(rangek1)
    scatter!(axis, fill(p, length(output[j])), output[j];
        color = ("green", 0.5), markersize = markersize)
end
ylims!(-3.0, 2.0)
display(fig)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
cd("images")

# %%
save("bif_dia_figure_5_length_1000_z_zero.pdf", fig)
# Out:
# CairoMakie.Screen{PDF}
