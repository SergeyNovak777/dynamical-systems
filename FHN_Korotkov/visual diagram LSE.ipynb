# %%
if Sys.iswindows()
    username = "Alex"
    pathtorepo = "C:\\Users\\" *username *  "\\Desktop\\"
    using Pkg
    Pkg.activate(pathtorepo * "dynamical-systems\\env\\integrate\\")
else
    username = "sergey"
    pathtorepo = "/home/" *username *"/work/repo/dynamical-systems"
    using Pkg
    Pkg.activate(pathtorepo * "/env/integrate/")
end

using JLD2, CairoMakie
# Out:
#   Activating project at `~/work/repo/dynamical-systems/env/integrate`

# %%
k1_start = 0.0
k1_end = 0.094
len = 3000
rangek1 = range(k1_start, k1_end, length = len)
# Out:
# 0.0:3.134378126042014e-5:0.094

# %%
LSE_s = (load("/home/sergey/work/repo/dynamical-systems/FHN_Korotkov/data/LSEs_k1_length_3000.jld2"))["LSEs"];
u0s = (load("/home/sergey/work/repo/dynamical-systems/FHN_Korotkov/data/u0s_k1_length_3000.jld2"))["u0ss"];

# %%
indexlc = 650
println(rangek1[indexlc])
println(LSE_s[indexlc, :])
println(u0s[indexlc, :])
# Out:
# 0.02034211403801267
# [-0.0005546637146654518, -8.658326491420227e-9, -0.16786779265653942, -Inf, -Inf]
# [-1.5013147125909783, -0.2777905873199756, -1.4567681374573005, -0.3322756258564975, -0.9455149614586514]

# %%
CairoMakie.activate!()
markersize = 1.5;
lbsize = 30;
ticksize = 30;
fig = Figure(size = (1200, 350))
axis = Axis(fig[1,1],
xlabel = L"k_1",  ylabel = L"x_1",
xlabelsize = lbsize, ylabelsize = lbsize,
xticklabelsize = ticksize,yticklabelsize = ticksize, xgridvisible = false, ygridvisible = false)

start_ = 1;end_ = 3000

lines!(axis, rangek1[start_:end_],  LSE_s[start_:end_, 1], color = :red)
lines!(axis, rangek1[start_:end_], LSE_s[start_:end_, 2], color = :green)
lines!(axis, rangek1[start_:end_], LSE_s[start_:end_, 3], color = :blue)

#ylims!(-0.05, 0.05)
display(fig)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
#cd("images")

# %%
#save("LSE_dia_figure_5_length_2000.pdf", fig)
# Out:
# CairoMakie.Screen{PDF}
