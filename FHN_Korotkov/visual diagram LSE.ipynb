# %%
if Sys.iswindows()
    username = "Alex"
    pathtorepo = "C:\\Users\\" *username *  "\\Desktop\\"
    using Pkg
    Pkg.activate(pathtorepo * "dynamical-systems\\env\\integrate\\")
else
    username = "sergey"
    pathtorepo = "/home/" *username *"/work/repo/dynamical-systems"
    using Pkg
    Pkg.activate(pathtorepo * "/env/integrate/")
end

using JLD2, CairoMakie
# Out:
#   Activating project at `~/work/repo/dynamical-systems/env/integrate`

# %%
k2_start = 0.0
k2_end = 100.0
len = 2000
range_param = range(k2_start, k2_end, length = len)
# Out:
# 0.0:0.05002501250625312:100.0

# %%
LSE_s = (load("/home/sergey/work/repo/dynamical-systems/FHN_Korotkov/data/LSEs_k2_length_2000_for_direction_1.jld2"))["LSEs"];
u0s = (load("/home/sergey/work/repo/dynamical-systems/FHN_Korotkov/data/u0s_k2_length_2000_for_direction_1.jld2"))["u0ss"];

# %%
range_param.step.hi
# Out:
# 9.409409409408265e-5

# %%
0.09004804804804804
[-1.023302718705447, -0.6367863085955093, -0.9957572704019987, -0.6365074822608355, -0.0053841715384289855]

# %%
indexlc = 958
println(range_param[indexlc])
println(LSE_s[indexlc, :])
println(u0s[indexlc, :])
# Out:
# 0.09004804804804804
# [0.03745102333496219, -5.142389818676861e-6, -0.001922262035139602, -Inf, -Inf]
# [-1.023302718705447, -0.6367863085955093, -0.9957572704019987, -0.6365074822608355, -0.0053841715384289855]

# %%
CairoMakie.activate!()
markersize = 1.5;
lbsize = 30;
ticksize = 30;
fig = Figure(size = (1200, 350))
axis = Axis(fig[1,1],
xlabel = L"k_2",  ylabel = L"x_1",
xlabelsize = lbsize, ylabelsize = lbsize,
xticklabelsize = ticksize,yticklabelsize = ticksize, xgridvisible = false, ygridvisible = false)

start_ = 1;end_ = 2000

lines!(axis, range_param[start_:end_],  LSE_s[start_:end_, 1], color = :red)
lines!(axis, range_param[start_:end_], LSE_s[start_:end_, 2], color = :green)
lines!(axis, range_param[start_:end_], LSE_s[start_:end_, 3], color = :blue)

#ylims!(-0.05, 0.05)
display(fig)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
cd("images")

# %%
save("LSE_dia_k2_length_2000_for_direction_1.pdf", fig)
# Out:
# CairoMakie.Screen{PDF}
