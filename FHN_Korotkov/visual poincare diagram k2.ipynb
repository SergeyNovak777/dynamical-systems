# %%
if Sys.iswindows()
    username = "Alex"
    pathtorepo = "C:\\Users\\" *username *  "\\Desktop\\"
    using Pkg
    Pkg.activate(pathtorepo * "dynamical-systems\\env\\integrate\\")
else
    username = "sergey"
    pathtorepo = "/home/" *username *"/work/repo/dynamical-systems"
    using Pkg
    Pkg.activate(pathtorepo * "/env/integrate/")
end

using JLD2, CairoMakie
# Out:
#   Activating project at `~/work/repo/dynamical-systems/env/integrate`

# %%
k2_start = 0.0
k2_end = 100.0
len = 2000
rangek1 = range(k2_start, k2_end, length = len)
# Out:
# 0.0:0.05002501250625312:100.0

# %%
output = (load("/home/sergey/work/repo/dynamical-systems/bif_dia_k2_length_2000_2000_secant_x2_-101_direction_1.jld2"))["output"]
# Out:
# 2000-element Vector{Vector{Float64}}:
#  [-1.0117106320919733, -1.0136018045334954, -1.0098162112997928, -1.9873963815991187, -1.0101833400070044, -1.0100313620738277, -1.010008516312621, -1.0100083466823406, -1.010015967233526, -1.0100333114697126  …  -1.012882586997349, -1.0152063931375366, -1.996231265715136, -1.0101827543785595, -1.0100319049580218, -1.0100096906809661, -1.0100108166805597, -1.0100211546035942, -1.0100441990741775, -1.0100927739509762]
#  [-1.010164190515932, -1.0103443178720386, -1.0107226533497906, -1.011522312404076, -1.0132139520147185, -1.0146055630825785, -1.9922296679180929, -1.0101829978820598, -1.0100316330803552, -1.010009106210583  …  -1.0100163906754183, -1.0100341904059562, -1.0100717777033776, -1.0101506220170677, -1.0103158730601067, -1.010662820826887, -1.011395437564372, -1.0129487643774326, -1.015174193521945, -1.9951385866172762]
# ...

# %%
CairoMakie.activate!()
markersize = 1.5;
lbsize = 30;
ticksize = 30;
fig = Figure(size = (1200, 350))
axis = Axis(fig[1,1],
xlabel = L"k_2",  ylabel = L"x_1",
xlabelsize = lbsize, ylabelsize = lbsize,
xticklabelsize = ticksize,yticklabelsize = ticksize, xgridvisible = false, ygridvisible = false,
xticks = [0.0, 20.0, 40.0, 60.0, 80.0, 100.0])

for (j, p) in enumerate(rangek1)
    scatter!(axis, fill(p, length(output[j])), output[j];
        color = ("green", 0.5), markersize = markersize)
end
ylims!(-2.5, 1.0)
display(fig)
# Out:
# CairoMakie.Screen{IMAGE}

# %%
cd("images")
# Out:
# IOError: cd("images"): no such file or directory (ENOENT)
#
#
#
# Stacktrace:
#
#  [1] uv_error
#
#    @ Base ./libuv.jl:100 [inlined]
#
#  [2] cd(dir::String)
#
#    @ Base.Filesystem ./file.jl:91
#
#  [3] top-level scope
#
#    @ ~/work/repo/dynamical-systems/FHN_Korotkov/visual poincare diagram k2.ipynb:1

# %%
save("bif_dia_k2_length_2000_2000_secant_x2_-101_direction_1.pdf", fig)
# Out:
# CairoMakie.Screen{PDF}
