# %%
user = "Alex"
pathtorepo = "C:\\Users\\" * user * "\\Desktop\\"

using Pkg
Pkg.activate(pathtorepo * "dynamical-systems\\env\\integrate\\")
include("C:\\Users\\" * user * "\\Desktop\\dynamical-systems\\system.jl")
# Out:
#   Activating project at `C:\Users\Alex\Desktop\dynamical-systems\env\integrate`
# jacob_TM_ (generic function with 1 method)

# %%
using JLD, CairoMakie

# %%
cd("c:\\Users\\Alex\\Desktop\\dynamical-systems\\HIndmarsh Rose memristor\\notebooks\\1d maps")

# %% [markdown]
# # 0.2.07.2023

# %%
Λs = load("LSs 100.jld")["data"];


k2me_start = 0.0
k2me_end = 1.0
k2me_length = 101

k2me_range = range(k2me_start, k2me_end, length = k2me_length)

lb_size = 30; tck_size = 25;

f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false)

lines!(axis, k2me_range, Λs[:, 1], linewidth = 2.5, color = :red)
lines!(axis, k2me_range, Λs[:, 2], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range, Λs[:, 3], linewidth = 2.5, color = :green)

f

# %%
Λs = load("LSs300.jld")["data"];


k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300

k2me_range = range(k2me_start, k2me_end, length = k2me_length)

lb_size = 30; tck_size = 25;

f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false)

lines!(axis, k2me_range, Λs[:, 1], linewidth = 2.5, color = :red)
lines!(axis, k2me_range, Λs[:, 2], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range, Λs[:, 3], linewidth = 2.5, color = :green)
f

# %%
Λs = load("LSs 300 inhib.jld")["data"];


k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300

k2me_range = range(k2me_start, k2me_end, length = k2me_length)

lb_size = 30; tck_size = 25;

f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false)

lines!(axis, k2me_range, Λs[:, 1], linewidth = 2.5, color = :red)
lines!(axis, k2me_range, Λs[:, 2], linewidth = 2.5, color = :orange)
f

# %%
Λs = load("LSs300 k1_me=0.1.jld")["data"];


k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300

k2me_range = range(k2me_start, k2me_end, length = k2me_length)

lb_size = 30; tck_size = 25;

f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false)

lines!(axis, k2me_range, Λs[:, 1], linewidth = 2.5, color = :red)
lines!(axis, k2me_range, Λs[:, 2], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range, Λs[:, 3], linewidth = 2.5, color = :green)
f

# %% [markdown]
# # 03.07.2023

# %%
# inhibitory k_1me = 0.2
Λs = load("LSs100 inhibitory k1_me=0.2.jld")["data"];
k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300
k2me_range = range(k2me_start, k2me_end, length = k2me_length)

lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false)

lines!(axis, k2me_range, Λs[:, 1], linewidth = 2.5, color = :red)
hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)

f

# %%
# inhibitory k_1me = 0.1
Λs = load("LSs100 inhibitory k1_me=0.1.jld")["data"];
k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300
k2me_range = range(k2me_start, k2me_end, length = k2me_length)
lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false)
lines!(axis, k2me_range, Λs[:, 7], linewidth = 2.5, color = :red)
lines!(axis, k2me_range, Λs[:, 6], linewidth = 2.5, color = :orange)
hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)

f

# %% [markdown]
# # chemical excitatory, change k1_me

# %%
# excitatory change  k_1me
Λs = load("LSs 300 excitatory change k1_me.jld")["data"];
k1me_start = 0.0
k1me_end = 1.0
k1me_length = 300
k1me_range = range(k1me_start, k1me_end, length = k1me_length)

st, ed = 1, 300
lb_size = 30; tck_size = 25;

f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{1 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Excitatory", titlesize = lb_size)

lines!(axis, k1me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k1me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k1me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis, k1me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)
vlines!(axis, k1me_range[57], color = :deeppink, linestyle = :dash, linewidth = 2.5)
hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)
f

# %%
index = 56
println("k1_me: ", k1me_range[index])
println("Λ1: ", Λs[index,7])
println("Λ2: ", Λs[index,6])
# Out:
# k1_me: 0.18394648829431437
# Λ1: 0.01281094254652268
# Λ2: 0.007872440098392842

# %% [markdown]
# ## excitatory k1_me = 0.183

# %%
# inhibitory k1_me=0.1103 index = 34
Λs = load("LSs100 excitatory k1_me = 0.183.jld")["data"];
k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300
k2me_range = range(k2me_start, k2me_end, length = k2me_length)
st, ed = 1, 300
lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Hyperchaos", titlesize = lb_size)

lines!(axis, k2me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
#lines!(axis, k2me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)
hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)

f

# %% [markdown]
# # chemical inhibitory change k1_me

# %%
# inhibitory change  k_1me
Λs = load("LSs 300 inhibitory change k1_me.jld")["data"];
k1me_start = 0.0
k1me_end = 1.0
k1me_length = 300
st, ed = 1, 300
k1me_range = range(k1me_start, k1me_end, length = k1me_length)
lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{1 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Inhibitory", titlesize = lb_size)

lines!(axis, k1me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k1me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k1me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis, k1me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)

vlines!(axis, k1me_range[34], color = :deeppink, linestyle = :dash, linewidth = 2.5)
vlines!(axis, k1me_range[61], color = :deeppink, linestyle = :dash, linewidth = 2.5)
vlines!(axis, k1me_range[100], color = :deeppink, linestyle = :dash, linewidth = 2.5)

hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)
f

# %%
index = 61
println("k1_me: ", k1me_range[index])
println("Λ1: ", Λs[index,7])
println("Λ2: ", Λs[index,6])
# Out:
# k1_me: 0.20066889632107024
# Λ1: 0.0005628981430341396
# Λ2: -0.0017962295467829847

# %% [markdown]
# ## inhibitory k1_me=0.1103 hyperchaos

# %%
# inhibitory k1_me=0.1103 index = 34
Λs = load("LSs100 inhibitory k1_me=0.1103.jld")["data"];
k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300
k2me_range = range(k2me_start, k2me_end, length = k2me_length)
st, ed = 1, 300
lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Hyperchaos", titlesize = lb_size)

lines!(axis, k2me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)
hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)

f

# %% [markdown]
# ## inhibitory k1_me=0.2 quasi

# %%
# inhibitory k1_me=0.2 quasi index = 61
Λs = load("LSs100 inhibitory k1_me=0.2 quasi.jld")["data"];
k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300
k2me_range = range(k2me_start, k2me_end, length = k2me_length)
st, ed = 1, 300
lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Quasi", titlesize = lb_size)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)
hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)
f

# %% [markdown]
# ## inhibitory k1_me=0.331 chaos

# %%
# inhibitory k1_me=0.331 chaos index = 100
Λs = load("LSs100 inhibitory k1_me=0.331 chaos.jld")["data"];

k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300
k2me_range = range(k2me_start, k2me_end, length = k2me_length)

st, ed = 1, 300

lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 300))

axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Chaos", titlesize = lb_size)

lines!(axis, k2me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)
hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)
f
