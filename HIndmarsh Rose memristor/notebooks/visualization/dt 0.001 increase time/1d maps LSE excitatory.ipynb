# %%
user = "Alex"
pathtorepo = "C:\\Users\\" * user * "\\Desktop\\"

using Pkg
Pkg.activate(pathtorepo * "dynamical-systems\\env\\integrate\\")
include("C:\\Users\\" * user * "\\Desktop\\dynamical-systems\\system.jl")
# Out:
#   Activating project at `C:\Users\Alex\Desktop\dynamical-systems\env\integrate`
# jacob_TM_ (generic function with 1 method)

# %%
using JLD, CairoMakie

# %%
cd("c:\\Users\\Alex\\Desktop\\dynamical-systems\\HIndmarsh Rose memristor\\notebooks\\1d maps")

# %% [markdown]
# # chemical excitatory

# %%
# excitatory change  k_1me
Λs = load("LSs 300 excitatory change k1_me.jld")["data"];
k1me_start = 0.0
k1me_end = 1.0
k1me_length = 300
k1me_range = range(k1me_start, k1me_end, length = k1me_length)

st, ed = 1, 300
lb_size = 30; tck_size = 25;

f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{1 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Excitatory", titlesize = lb_size)

lines!(axis, k1me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k1me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k1me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis, k1me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)

vlines!(axis, k1me_range[57], color = :deeppink, linestyle = :dash, linewidth = 2.5)
vlines!(axis, k1me_range[80], color = :deeppink, linestyle = :dash, linewidth = 2.5)
vlines!(axis, k1me_range[124], color = :deeppink, linestyle = :dash, linewidth = 2.5)

hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)
f

# %%
index = 80
println("k1_me: ", k1me_range[index])
println("Λ1: ", Λs[index,7])
println("Λ2: ", Λs[index,6])
println("Λ3: ", Λs[index,5])
# Out:
# k1_me: 0.26421404682274247
# Λ1: 0.00783629222817537
# Λ2: -0.0003960114277984471
# Λ3: -0.0019423030833594541

# %% [markdown]
# ## excitatory k1_me = 0.183 hyperchaos

# %%
# excitatory k1_me=0.18394648829431437 index = 56
Λs = load("LSs100 excitatory k1_me = 0.183.jld")["data"];
k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300
k2me_range = range(k2me_start, k2me_end, length = k2me_length)
st, ed = 1, 300
lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Hyperchaos", titlesize = lb_size)

lines!(axis, k2me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)

hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)
f

# %% [markdown]
# ## excitatory k1_me = 0.264 quasi

# %%
# excitatory k1_me=0.26421404682274247, index = 80
Λs = load("LSs100 excitatory k1_me = 0.264.jld")["data"];
k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300
k2me_range = range(k2me_start, k2me_end, length = k2me_length)
st, ed = 1, 300
lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Quasi", titlesize = lb_size)

lines!(axis, k2me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)

hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)
f

# %% [markdown]
# ## excitatory k1_me = 0.411 chaos

# %%
# excitatory k1_me = 0.411 index = 124
Λs = load("LSs100 excitatory k1_me = 0.411.jld")["data"];
k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300
k2me_range = range(k2me_start, k2me_end, length = k2me_length)
st, ed = 1, 300
lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Chaos", titlesize = lb_size)

lines!(axis, k2me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)

hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)
f
