# %%
user = "Alex"
pathtorepo = "C:\\Users\\" * user * "\\Desktop\\"

using Pkg
Pkg.activate(pathtorepo * "dynamical-systems\\env\\integrate\\")
# Out:
#   Activating project at `C:\Users\Alex\Desktop\dynamical-systems\env\integrate`

# %%
using JLD, CairoMakie

# %%
cd("c:\\Users\\Alex\\Desktop\\dynamical-systems\\HIndmarsh Rose memristor\\notebooks\\1d maps\\dt 0.001 k1 to 10")

# %% [markdown]
# # chemical inhibitory change k1_me

# %%
# inhibitory change  k_1me
Λs = load("LSs 300 inhibitory change k1_me to 1.jld")["data"];
Es = load("EEs 300 inhibitory change k1_me to 1.jld")["data"];
u0s = load("u0s 300 inhibitory change k1_me to 1.jld")["data"];

k1me_start = 0.0
k1me_end = 1.0
k1me_length = 299
st, ed = 1, 299
k1me_range = range(k1me_start, k1me_end, length = k1me_length)
lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 500))
axis1 = Axis(f[1, 1], xlabel = L"k_{1 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Inhibitory", titlesize = lb_size)

axis2 = Axis(f[2, 1], xlabel = L"k_{1 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Inhibitory", titlesize = lb_size)

lines!(axis1, k1me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis1, k1me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis1, k1me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis1, k1me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)
hlines!(axis1, 0.0, linestyle = :dash, color = :black, linewidth = 0.5)

lines!(axis1, k1me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)

#vlines!(axis, k1me_range[34], color = :deeppink, linestyle = :dash, linewidth = 2.5)
#vlines!(axis, k1me_range[61], color = :deeppink, linestyle = :dash, linewidth = 2.5)
#vlines!(axis, k1me_range[100], color = :deeppink, linestyle = :dash, linewidth = 2.5)


lines!(axis2, k1me_range[st:ed], Es[st:ed], linewidth = 2.5, color = :deeppink)

f

# %%
index = 62
println("k1_me: ", k1me_range[index])
println("u0s: ", u0s[index, :])
println("Es: ", Es[index])
println()
println("Λ1: ", Λs[index,7])
println("Λ2: ", Λs[index,6])
println("Λ3: ", Λs[index,5])
println("Λ4: ", Λs[index,4])
# Out:
# k1_me: 0.20469798657718122
# u0s: [0.20736132434341792, 0.8462336012092696, 4.271279082481563, -1.3535769496300754, -8.262082950361135, 3.456458643962085, 421.19939287725674]
# Es: 0.0
#
# Λ1: 0.0005142300384601682
# Λ2: -0.0006577132672858886
# Λ3: -0.007489908864916702
# Λ4: -0.01980032537839542

# %% [markdown]
# ## inhibitory k1_me=0.09698996655518395 hyperchaos

# %%
LSs 500 inhibitory k1_me=0.030.jld
LSs 500 inhibitory k1_me=0.096.jld

# %%
# inhibitory k1_me=0.096 index = 30
Λs = load("LSs 500 inhibitory k1_me=0.030.jld")["data"]
Es = load("EEs 500 inhibitory k1_me=0.030.jld")["data"]
u0s = load("u0s 500 inhibitory k1_me=0.030.jld")["data"]

k2me_start = 0.0
k2me_end = 10.0
k2me_length = 500
k2me_range = range(k2me_start, k2me_end, length = k2me_length)
st, ed = 1, 500

lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 500))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Hyperchaos", titlesize = lb_size)


lines!(axis, k2me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)

#lines!(axis, k2me_range[st:ed], Λs[st:ed, 1], linewidth = 2.5, color = :deeppink)

hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)

f

# %% [markdown]
# ## inhibitory k1_me=0.332 chaos

# %%
# inhibitory k1_me=0.332 chaos index = 100
Λs = load("LSs 500 inhibitory k1_me=0.332.jld")["data"];

k2me_start = 0.0
k2me_end = 10.0
k2me_length = 500
k2me_range = range(k2me_start, k2me_end, length = k2me_length)

st, ed = 1, 500

lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 300))

axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Chaos", titlesize = lb_size)

lines!(axis, k2me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)
    
hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)
f

# %% [markdown]
# ## inhibitory k1_me=0.2 quasi

# %%
# inhibitory k1_me=0.2 quasi index = 61
Λs = load("LSs 500 inhibitory k1_me=0.204.jld")["data"];
k2me_start = 0.0
k2me_end = 1.0
k2me_length = 300
k2me_range = range(k2me_start, k2me_end, length = k2me_length)
st, ed = 1, 300
lb_size = 30; tck_size = 25;
f = Figure(resolution = (1200, 300))
axis = Axis(f[1, 1], xlabel = L"k_{2 memr}", ylabel = L"\Lambda s",
            xlabelsize = lb_size, ylabelsize = lb_size,
            xticklabelsize = tck_size, yticklabelsize = tck_size,
            xgridvisible = false, ygridvisible = false, title = L"Quasi", titlesize = lb_size)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 7], linewidth = 2.5, color = :red)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 6], linewidth = 2.5, color = :orange)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 5], linewidth = 2.5, color = :green)
lines!(axis, k2me_range[st:ed], Λs[st:ed, 4], linewidth = 2.5, color = :blue)
hlines!(axis, 0.0, linestyle = :dash, color = :black, linewidth = 2.0)
f
